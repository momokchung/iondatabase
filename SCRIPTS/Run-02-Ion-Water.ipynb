# %%
import os
import ion_gen as ig

# %%
psi4Exe = "/home/kchung25/anaconda3/envs/psi4_19/bin/psi4"
qchemExe = "/home/kchung25/qchem/5.4.0/bin/qchem"

cwd = os.getcwd()

# %%
# MP2

mp2Dir = f"{cwd}/../MP2"
os.chdir(mp2Dir)

for key,item in ig.ionWaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_mp2.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# SAPT2+

saptDir = f"{cwd}/../SAPT2+"
os.chdir(saptDir)

for key,item in ig.ionWaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_sapt.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# ALMO

almoDir = f"{cwd}/../ALMO"
os.chdir(almoDir)

for key,item in ig.ionWaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileNameIn = f"{index}_{key}_{dist:3.2f}_almo.in"
        fileNameOut = f"{index}_{key}_{dist:3.2f}_almo.out"
        os.system(f"{qchemExe} -np 6 -nt 6 {fileNameIn} {fileNameOut}")
# Out:
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_0.80_almo.in
# output file: 010_Li-Water_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160161
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160161
# QCSAVEDIR:
# workdirs:    /scratch/qchem160161.0 -- /scratch/qchem160161.5
# workdir0:    /scratch/qchem160161.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160161.0 -- /scratch/qchem160161.5
# rm -rf /scratch/qchem160161.0
# rm -rf /scratch/qchem160161.1
# rm -rf /scratch/qchem160161.2
# rm -rf /scratch/qchem160161.3
# rm -rf /scratch/qchem160161.4
# rm -rf /scratch/qchem160161.5
# rm -rf /scratch/qchem160161
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_0.90_almo.in
# output file: 010_Li-Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160245
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160245
# QCSAVEDIR:
# workdirs:    /scratch/qchem160245.0 -- /scratch/qchem160245.5
# workdir0:    /scratch/qchem160245.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160245.0 -- /scratch/qchem160245.5
# rm -rf /scratch/qchem160245.0
# rm -rf /scratch/qchem160245.1
# rm -rf /scratch/qchem160245.2
# rm -rf /scratch/qchem160245.3
# rm -rf /scratch/qchem160245.4
# rm -rf /scratch/qchem160245.5
# rm -rf /scratch/qchem160245
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_0.95_almo.in
# output file: 010_Li-Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160337
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160337
# QCSAVEDIR:
# workdirs:    /scratch/qchem160337.0 -- /scratch/qchem160337.5
# workdir0:    /scratch/qchem160337.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160337.0 -- /scratch/qchem160337.5
# rm -rf /scratch/qchem160337.0
# rm -rf /scratch/qchem160337.1
# rm -rf /scratch/qchem160337.2
# rm -rf /scratch/qchem160337.3
# rm -rf /scratch/qchem160337.4
# rm -rf /scratch/qchem160337.5
# rm -rf /scratch/qchem160337
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.00_almo.in
# output file: 010_Li-Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160430
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160430
# QCSAVEDIR:
# workdirs:    /scratch/qchem160430.0 -- /scratch/qchem160430.5
# workdir0:    /scratch/qchem160430.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160430.0 -- /scratch/qchem160430.5
# rm -rf /scratch/qchem160430.0
# rm -rf /scratch/qchem160430.1
# rm -rf /scratch/qchem160430.2
# rm -rf /scratch/qchem160430.3
# rm -rf /scratch/qchem160430.4
# rm -rf /scratch/qchem160430.5
# rm -rf /scratch/qchem160430
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.05_almo.in
# output file: 010_Li-Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160531
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160531
# QCSAVEDIR:
# workdirs:    /scratch/qchem160531.0 -- /scratch/qchem160531.5
# workdir0:    /scratch/qchem160531.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160531.0 -- /scratch/qchem160531.5
# rm -rf /scratch/qchem160531.0
# rm -rf /scratch/qchem160531.1
# rm -rf /scratch/qchem160531.2
# rm -rf /scratch/qchem160531.3
# rm -rf /scratch/qchem160531.4
# rm -rf /scratch/qchem160531.5
# rm -rf /scratch/qchem160531
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.10_almo.in
# output file: 010_Li-Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160623
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160623
# QCSAVEDIR:
# workdirs:    /scratch/qchem160623.0 -- /scratch/qchem160623.5
# workdir0:    /scratch/qchem160623.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160623.0 -- /scratch/qchem160623.5
# rm -rf /scratch/qchem160623.0
# rm -rf /scratch/qchem160623.1
# rm -rf /scratch/qchem160623.2
# rm -rf /scratch/qchem160623.3
# rm -rf /scratch/qchem160623.4
# rm -rf /scratch/qchem160623.5
# rm -rf /scratch/qchem160623
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.20_almo.in
# output file: 010_Li-Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160717
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160717
# QCSAVEDIR:
# workdirs:    /scratch/qchem160717.0 -- /scratch/qchem160717.5
# workdir0:    /scratch/qchem160717.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160717.0 -- /scratch/qchem160717.5
# rm -rf /scratch/qchem160717.0
# rm -rf /scratch/qchem160717.1
# rm -rf /scratch/qchem160717.2
# rm -rf /scratch/qchem160717.3
# rm -rf /scratch/qchem160717.4
# rm -rf /scratch/qchem160717.5
# rm -rf /scratch/qchem160717
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.30_almo.in
# output file: 010_Li-Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160813
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160813
# QCSAVEDIR:
# workdirs:    /scratch/qchem160813.0 -- /scratch/qchem160813.5
# workdir0:    /scratch/qchem160813.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160813.0 -- /scratch/qchem160813.5
# rm -rf /scratch/qchem160813.0
# rm -rf /scratch/qchem160813.1
# rm -rf /scratch/qchem160813.2
# rm -rf /scratch/qchem160813.3
# rm -rf /scratch/qchem160813.4
# rm -rf /scratch/qchem160813.5
# rm -rf /scratch/qchem160813
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.40_almo.in
# output file: 010_Li-Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160905
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160905
# QCSAVEDIR:
# workdirs:    /scratch/qchem160905.0 -- /scratch/qchem160905.5
# workdir0:    /scratch/qchem160905.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160905.0 -- /scratch/qchem160905.5
# rm -rf /scratch/qchem160905.0
# rm -rf /scratch/qchem160905.1
# rm -rf /scratch/qchem160905.2
# rm -rf /scratch/qchem160905.3
# rm -rf /scratch/qchem160905.4
# rm -rf /scratch/qchem160905.5
# rm -rf /scratch/qchem160905
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_1.50_almo.in
# output file: 010_Li-Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem160996
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem160996
# QCSAVEDIR:
# workdirs:    /scratch/qchem160996.0 -- /scratch/qchem160996.5
# workdir0:    /scratch/qchem160996.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem160996.0 -- /scratch/qchem160996.5
# rm -rf /scratch/qchem160996.0
# rm -rf /scratch/qchem160996.1
# rm -rf /scratch/qchem160996.2
# rm -rf /scratch/qchem160996.3
# rm -rf /scratch/qchem160996.4
# rm -rf /scratch/qchem160996.5
# rm -rf /scratch/qchem160996
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  010_Li-Water_2.00_almo.in
# output file: 010_Li-Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161092
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161092
# QCSAVEDIR:
# workdirs:    /scratch/qchem161092.0 -- /scratch/qchem161092.5
# workdir0:    /scratch/qchem161092.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161092.0 -- /scratch/qchem161092.5
# rm -rf /scratch/qchem161092.0
# rm -rf /scratch/qchem161092.1
# rm -rf /scratch/qchem161092.2
# rm -rf /scratch/qchem161092.3
# rm -rf /scratch/qchem161092.4
# rm -rf /scratch/qchem161092.5
# rm -rf /scratch/qchem161092
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_0.80_almo.in
# output file: 011_Na-Water_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161189
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161189
# QCSAVEDIR:
# workdirs:    /scratch/qchem161189.0 -- /scratch/qchem161189.5
# workdir0:    /scratch/qchem161189.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161189.0 -- /scratch/qchem161189.5
# rm -rf /scratch/qchem161189.0
# rm -rf /scratch/qchem161189.1
# rm -rf /scratch/qchem161189.2
# rm -rf /scratch/qchem161189.3
# rm -rf /scratch/qchem161189.4
# rm -rf /scratch/qchem161189.5
# rm -rf /scratch/qchem161189
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_0.90_almo.in
# output file: 011_Na-Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161310
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161310
# QCSAVEDIR:
# workdirs:    /scratch/qchem161310.0 -- /scratch/qchem161310.5
# workdir0:    /scratch/qchem161310.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161310.0 -- /scratch/qchem161310.5
# rm -rf /scratch/qchem161310.0
# rm -rf /scratch/qchem161310.1
# rm -rf /scratch/qchem161310.2
# rm -rf /scratch/qchem161310.3
# rm -rf /scratch/qchem161310.4
# rm -rf /scratch/qchem161310.5
# rm -rf /scratch/qchem161310
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_0.95_almo.in
# output file: 011_Na-Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161430
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161430
# QCSAVEDIR:
# workdirs:    /scratch/qchem161430.0 -- /scratch/qchem161430.5
# workdir0:    /scratch/qchem161430.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161430.0 -- /scratch/qchem161430.5
# rm -rf /scratch/qchem161430.0
# rm -rf /scratch/qchem161430.1
# rm -rf /scratch/qchem161430.2
# rm -rf /scratch/qchem161430.3
# rm -rf /scratch/qchem161430.4
# rm -rf /scratch/qchem161430.5
# rm -rf /scratch/qchem161430
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.00_almo.in
# output file: 011_Na-Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161555
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161555
# QCSAVEDIR:
# workdirs:    /scratch/qchem161555.0 -- /scratch/qchem161555.5
# workdir0:    /scratch/qchem161555.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161555.0 -- /scratch/qchem161555.5
# rm -rf /scratch/qchem161555.0
# rm -rf /scratch/qchem161555.1
# rm -rf /scratch/qchem161555.2
# rm -rf /scratch/qchem161555.3
# rm -rf /scratch/qchem161555.4
# rm -rf /scratch/qchem161555.5
# rm -rf /scratch/qchem161555
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.05_almo.in
# output file: 011_Na-Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161650
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161650
# QCSAVEDIR:
# workdirs:    /scratch/qchem161650.0 -- /scratch/qchem161650.5
# workdir0:    /scratch/qchem161650.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161650.0 -- /scratch/qchem161650.5
# rm -rf /scratch/qchem161650.0
# rm -rf /scratch/qchem161650.1
# rm -rf /scratch/qchem161650.2
# rm -rf /scratch/qchem161650.3
# rm -rf /scratch/qchem161650.4
# rm -rf /scratch/qchem161650.5
# rm -rf /scratch/qchem161650
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.10_almo.in
# output file: 011_Na-Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161752
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161752
# QCSAVEDIR:
# workdirs:    /scratch/qchem161752.0 -- /scratch/qchem161752.5
# workdir0:    /scratch/qchem161752.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161752.0 -- /scratch/qchem161752.5
# rm -rf /scratch/qchem161752.0
# rm -rf /scratch/qchem161752.1
# rm -rf /scratch/qchem161752.2
# rm -rf /scratch/qchem161752.3
# rm -rf /scratch/qchem161752.4
# rm -rf /scratch/qchem161752.5
# rm -rf /scratch/qchem161752
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.20_almo.in
# output file: 011_Na-Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161857
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161857
# QCSAVEDIR:
# workdirs:    /scratch/qchem161857.0 -- /scratch/qchem161857.5
# workdir0:    /scratch/qchem161857.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161857.0 -- /scratch/qchem161857.5
# rm -rf /scratch/qchem161857.0
# rm -rf /scratch/qchem161857.1
# rm -rf /scratch/qchem161857.2
# rm -rf /scratch/qchem161857.3
# rm -rf /scratch/qchem161857.4
# rm -rf /scratch/qchem161857.5
# rm -rf /scratch/qchem161857
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.30_almo.in
# output file: 011_Na-Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem161952
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem161952
# QCSAVEDIR:
# workdirs:    /scratch/qchem161952.0 -- /scratch/qchem161952.5
# workdir0:    /scratch/qchem161952.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem161952.0 -- /scratch/qchem161952.5
# rm -rf /scratch/qchem161952.0
# rm -rf /scratch/qchem161952.1
# rm -rf /scratch/qchem161952.2
# rm -rf /scratch/qchem161952.3
# rm -rf /scratch/qchem161952.4
# rm -rf /scratch/qchem161952.5
# rm -rf /scratch/qchem161952
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.40_almo.in
# output file: 011_Na-Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162077
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162077
# QCSAVEDIR:
# workdirs:    /scratch/qchem162077.0 -- /scratch/qchem162077.5
# workdir0:    /scratch/qchem162077.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162077.0 -- /scratch/qchem162077.5
# rm -rf /scratch/qchem162077.0
# rm -rf /scratch/qchem162077.1
# rm -rf /scratch/qchem162077.2
# rm -rf /scratch/qchem162077.3
# rm -rf /scratch/qchem162077.4
# rm -rf /scratch/qchem162077.5
# rm -rf /scratch/qchem162077
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_1.50_almo.in
# output file: 011_Na-Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162172
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162172
# QCSAVEDIR:
# workdirs:    /scratch/qchem162172.0 -- /scratch/qchem162172.5
# workdir0:    /scratch/qchem162172.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162172.0 -- /scratch/qchem162172.5
# rm -rf /scratch/qchem162172.0
# rm -rf /scratch/qchem162172.1
# rm -rf /scratch/qchem162172.2
# rm -rf /scratch/qchem162172.3
# rm -rf /scratch/qchem162172.4
# rm -rf /scratch/qchem162172.5
# rm -rf /scratch/qchem162172
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  011_Na-Water_2.00_almo.in
# output file: 011_Na-Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162266
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162266
# QCSAVEDIR:
# workdirs:    /scratch/qchem162266.0 -- /scratch/qchem162266.5
# workdir0:    /scratch/qchem162266.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162266.0 -- /scratch/qchem162266.5
# rm -rf /scratch/qchem162266.0
# rm -rf /scratch/qchem162266.1
# rm -rf /scratch/qchem162266.2
# rm -rf /scratch/qchem162266.3
# rm -rf /scratch/qchem162266.4
# rm -rf /scratch/qchem162266.5
# rm -rf /scratch/qchem162266
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_0.80_almo.in
# output file: 012_K-Water_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162360
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162360
# QCSAVEDIR:
# workdirs:    /scratch/qchem162360.0 -- /scratch/qchem162360.5
# workdir0:    /scratch/qchem162360.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162360.0 -- /scratch/qchem162360.5
# rm -rf /scratch/qchem162360.0
# rm -rf /scratch/qchem162360.1
# rm -rf /scratch/qchem162360.2
# rm -rf /scratch/qchem162360.3
# rm -rf /scratch/qchem162360.4
# rm -rf /scratch/qchem162360.5
# rm -rf /scratch/qchem162360
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_0.90_almo.in
# output file: 012_K-Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162486
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162486
# QCSAVEDIR:
# workdirs:    /scratch/qchem162486.0 -- /scratch/qchem162486.5
# workdir0:    /scratch/qchem162486.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162486.0 -- /scratch/qchem162486.5
# rm -rf /scratch/qchem162486.0
# rm -rf /scratch/qchem162486.1
# rm -rf /scratch/qchem162486.2
# rm -rf /scratch/qchem162486.3
# rm -rf /scratch/qchem162486.4
# rm -rf /scratch/qchem162486.5
# rm -rf /scratch/qchem162486
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_0.95_almo.in
# output file: 012_K-Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162614
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162614
# QCSAVEDIR:
# workdirs:    /scratch/qchem162614.0 -- /scratch/qchem162614.5
# workdir0:    /scratch/qchem162614.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162614.0 -- /scratch/qchem162614.5
# rm -rf /scratch/qchem162614.0
# rm -rf /scratch/qchem162614.1
# rm -rf /scratch/qchem162614.2
# rm -rf /scratch/qchem162614.3
# rm -rf /scratch/qchem162614.4
# rm -rf /scratch/qchem162614.5
# rm -rf /scratch/qchem162614
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.00_almo.in
# output file: 012_K-Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162738
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162738
# QCSAVEDIR:
# workdirs:    /scratch/qchem162738.0 -- /scratch/qchem162738.5
# workdir0:    /scratch/qchem162738.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162738.0 -- /scratch/qchem162738.5
# rm -rf /scratch/qchem162738.0
# rm -rf /scratch/qchem162738.1
# rm -rf /scratch/qchem162738.2
# rm -rf /scratch/qchem162738.3
# rm -rf /scratch/qchem162738.4
# rm -rf /scratch/qchem162738.5
# rm -rf /scratch/qchem162738
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.05_almo.in
# output file: 012_K-Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162858
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162858
# QCSAVEDIR:
# workdirs:    /scratch/qchem162858.0 -- /scratch/qchem162858.5
# workdir0:    /scratch/qchem162858.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162858.0 -- /scratch/qchem162858.5
# rm -rf /scratch/qchem162858.0
# rm -rf /scratch/qchem162858.1
# rm -rf /scratch/qchem162858.2
# rm -rf /scratch/qchem162858.3
# rm -rf /scratch/qchem162858.4
# rm -rf /scratch/qchem162858.5
# rm -rf /scratch/qchem162858
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.10_almo.in
# output file: 012_K-Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem162979
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem162979
# QCSAVEDIR:
# workdirs:    /scratch/qchem162979.0 -- /scratch/qchem162979.5
# workdir0:    /scratch/qchem162979.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem162979.0 -- /scratch/qchem162979.5
# rm -rf /scratch/qchem162979.0
# rm -rf /scratch/qchem162979.1
# rm -rf /scratch/qchem162979.2
# rm -rf /scratch/qchem162979.3
# rm -rf /scratch/qchem162979.4
# rm -rf /scratch/qchem162979.5
# rm -rf /scratch/qchem162979
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.20_almo.in
# output file: 012_K-Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163103
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163103
# QCSAVEDIR:
# workdirs:    /scratch/qchem163103.0 -- /scratch/qchem163103.5
# workdir0:    /scratch/qchem163103.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163103.0 -- /scratch/qchem163103.5
# rm -rf /scratch/qchem163103.0
# rm -rf /scratch/qchem163103.1
# rm -rf /scratch/qchem163103.2
# rm -rf /scratch/qchem163103.3
# rm -rf /scratch/qchem163103.4
# rm -rf /scratch/qchem163103.5
# rm -rf /scratch/qchem163103
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.30_almo.in
# output file: 012_K-Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163226
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163226
# QCSAVEDIR:
# workdirs:    /scratch/qchem163226.0 -- /scratch/qchem163226.5
# workdir0:    /scratch/qchem163226.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163226.0 -- /scratch/qchem163226.5
# rm -rf /scratch/qchem163226.0
# rm -rf /scratch/qchem163226.1
# rm -rf /scratch/qchem163226.2
# rm -rf /scratch/qchem163226.3
# rm -rf /scratch/qchem163226.4
# rm -rf /scratch/qchem163226.5
# rm -rf /scratch/qchem163226
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.40_almo.in
# output file: 012_K-Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163344
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163344
# QCSAVEDIR:
# workdirs:    /scratch/qchem163344.0 -- /scratch/qchem163344.5
# workdir0:    /scratch/qchem163344.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163344.0 -- /scratch/qchem163344.5
# rm -rf /scratch/qchem163344.0
# rm -rf /scratch/qchem163344.1
# rm -rf /scratch/qchem163344.2
# rm -rf /scratch/qchem163344.3
# rm -rf /scratch/qchem163344.4
# rm -rf /scratch/qchem163344.5
# rm -rf /scratch/qchem163344
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_1.50_almo.in
# output file: 012_K-Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163472
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163472
# QCSAVEDIR:
# workdirs:    /scratch/qchem163472.0 -- /scratch/qchem163472.5
# workdir0:    /scratch/qchem163472.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163472.0 -- /scratch/qchem163472.5
# rm -rf /scratch/qchem163472.0
# rm -rf /scratch/qchem163472.1
# rm -rf /scratch/qchem163472.2
# rm -rf /scratch/qchem163472.3
# rm -rf /scratch/qchem163472.4
# rm -rf /scratch/qchem163472.5
# rm -rf /scratch/qchem163472
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  012_K-Water_2.00_almo.in
# output file: 012_K-Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163588
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163588
# QCSAVEDIR:
# workdirs:    /scratch/qchem163588.0 -- /scratch/qchem163588.5
# workdir0:    /scratch/qchem163588.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163588.0 -- /scratch/qchem163588.5
# rm -rf /scratch/qchem163588.0
# rm -rf /scratch/qchem163588.1
# rm -rf /scratch/qchem163588.2
# rm -rf /scratch/qchem163588.3
# rm -rf /scratch/qchem163588.4
# rm -rf /scratch/qchem163588.5
# rm -rf /scratch/qchem163588
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  013_F-Water_0.80_almo.in
# output file: 013_F-Water_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163706
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163706
# QCSAVEDIR:
# workdirs:    /scratch/qchem163706.0 -- /scratch/qchem163706.5
# workdir0:    /scratch/qchem163706.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163706.0 -- /scratch/qchem163706.5
# rm -rf /scratch/qchem163706.0
# rm -rf /scratch/qchem163706.1
# rm -rf /scratch/qchem163706.2
# rm -rf /scratch/qchem163706.3
# rm -rf /scratch/qchem163706.4
# rm -rf /scratch/qchem163706.5
# rm -rf /scratch/qchem163706
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  013_F-Water_0.90_almo.in
# output file: 013_F-Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163838
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163838
# QCSAVEDIR:
# workdirs:    /scratch/qchem163838.0 -- /scratch/qchem163838.5
# workdir0:    /scratch/qchem163838.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163838.0 -- /scratch/qchem163838.5
# rm -rf /scratch/qchem163838.0
# rm -rf /scratch/qchem163838.1
# rm -rf /scratch/qchem163838.2
# rm -rf /scratch/qchem163838.3
# rm -rf /scratch/qchem163838.4
# rm -rf /scratch/qchem163838.5
# rm -rf /scratch/qchem163838
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  013_F-Water_0.95_almo.in
# output file: 013_F-Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem163959
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem163959
# QCSAVEDIR:
# workdirs:    /scratch/qchem163959.0 -- /scratch/qchem163959.5
# workdir0:    /scratch/qchem163959.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem163959.0 -- /scratch/qchem163959.5
# rm -rf /scratch/qchem163959.0
# rm -rf /scratch/qchem163959.1
# rm -rf /scratch/qchem163959.2
# rm -rf /scratch/qchem163959.3
# rm -rf /scratch/qchem163959.4
# rm -rf /scratch/qchem163959.5
# rm -rf /scratch/qchem163959
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  013_F-Water_1.00_almo.in
# output file: 013_F-Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# ...
# rm -rf /scratch/qchem166202.2
# rm -rf /scratch/qchem166202.3
# rm -rf /scratch/qchem166202.4
# rm -rf /scratch/qchem166202.5
# rm -rf /scratch/qchem166202
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  014_Cl-Water_2.00_almo.in
# output file: 014_Cl-Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem166327
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem166327
# QCSAVEDIR:
# workdirs:    /scratch/qchem166327.0 -- /scratch/qchem166327.5
# workdir0:    /scratch/qchem166327.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem166327.0 -- /scratch/qchem166327.5
# rm -rf /scratch/qchem166327.0
# rm -rf /scratch/qchem166327.1
# rm -rf /scratch/qchem166327.2
# rm -rf /scratch/qchem166327.3
# rm -rf /scratch/qchem166327.4
# rm -rf /scratch/qchem166327.5
# rm -rf /scratch/qchem166327
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_0.80_almo.in
# output file: 015_Br-Water_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem166443
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem166443
# QCSAVEDIR:
# workdirs:    /scratch/qchem166443.0 -- /scratch/qchem166443.5
# workdir0:    /scratch/qchem166443.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem166443.0 -- /scratch/qchem166443.5
# rm -rf /scratch/qchem166443.0
# rm -rf /scratch/qchem166443.1
# rm -rf /scratch/qchem166443.2
# rm -rf /scratch/qchem166443.3
# rm -rf /scratch/qchem166443.4
# rm -rf /scratch/qchem166443.5
# rm -rf /scratch/qchem166443
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_0.90_almo.in
# output file: 015_Br-Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem166615
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem166615
# QCSAVEDIR:
# workdirs:    /scratch/qchem166615.0 -- /scratch/qchem166615.5
# workdir0:    /scratch/qchem166615.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem166615.0 -- /scratch/qchem166615.5
# rm -rf /scratch/qchem166615.0
# rm -rf /scratch/qchem166615.1
# rm -rf /scratch/qchem166615.2
# rm -rf /scratch/qchem166615.3
# rm -rf /scratch/qchem166615.4
# rm -rf /scratch/qchem166615.5
# rm -rf /scratch/qchem166615
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_0.95_almo.in
# output file: 015_Br-Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem166773
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem166773
# QCSAVEDIR:
# workdirs:    /scratch/qchem166773.0 -- /scratch/qchem166773.5
# workdir0:    /scratch/qchem166773.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem166773.0 -- /scratch/qchem166773.5
# rm -rf /scratch/qchem166773.0
# rm -rf /scratch/qchem166773.1
# rm -rf /scratch/qchem166773.2
# rm -rf /scratch/qchem166773.3
# rm -rf /scratch/qchem166773.4
# rm -rf /scratch/qchem166773.5
# rm -rf /scratch/qchem166773
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.00_almo.in
# output file: 015_Br-Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem166920
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem166920
# QCSAVEDIR:
# workdirs:    /scratch/qchem166920.0 -- /scratch/qchem166920.5
# workdir0:    /scratch/qchem166920.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem166920.0 -- /scratch/qchem166920.5
# rm -rf /scratch/qchem166920.0
# rm -rf /scratch/qchem166920.1
# rm -rf /scratch/qchem166920.2
# rm -rf /scratch/qchem166920.3
# rm -rf /scratch/qchem166920.4
# rm -rf /scratch/qchem166920.5
# rm -rf /scratch/qchem166920
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.05_almo.in
# output file: 015_Br-Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167078
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167078
# QCSAVEDIR:
# workdirs:    /scratch/qchem167078.0 -- /scratch/qchem167078.5
# workdir0:    /scratch/qchem167078.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167078.0 -- /scratch/qchem167078.5
# rm -rf /scratch/qchem167078.0
# rm -rf /scratch/qchem167078.1
# rm -rf /scratch/qchem167078.2
# rm -rf /scratch/qchem167078.3
# rm -rf /scratch/qchem167078.4
# rm -rf /scratch/qchem167078.5
# rm -rf /scratch/qchem167078
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.10_almo.in
# output file: 015_Br-Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167221
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167221
# QCSAVEDIR:
# workdirs:    /scratch/qchem167221.0 -- /scratch/qchem167221.5
# workdir0:    /scratch/qchem167221.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167221.0 -- /scratch/qchem167221.5
# rm -rf /scratch/qchem167221.0
# rm -rf /scratch/qchem167221.1
# rm -rf /scratch/qchem167221.2
# rm -rf /scratch/qchem167221.3
# rm -rf /scratch/qchem167221.4
# rm -rf /scratch/qchem167221.5
# rm -rf /scratch/qchem167221
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.20_almo.in
# output file: 015_Br-Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167356
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167356
# QCSAVEDIR:
# workdirs:    /scratch/qchem167356.0 -- /scratch/qchem167356.5
# workdir0:    /scratch/qchem167356.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167356.0 -- /scratch/qchem167356.5
# rm -rf /scratch/qchem167356.0
# rm -rf /scratch/qchem167356.1
# rm -rf /scratch/qchem167356.2
# rm -rf /scratch/qchem167356.3
# rm -rf /scratch/qchem167356.4
# rm -rf /scratch/qchem167356.5
# rm -rf /scratch/qchem167356
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.30_almo.in
# output file: 015_Br-Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167499
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167499
# QCSAVEDIR:
# workdirs:    /scratch/qchem167499.0 -- /scratch/qchem167499.5
# workdir0:    /scratch/qchem167499.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167499.0 -- /scratch/qchem167499.5
# rm -rf /scratch/qchem167499.0
# rm -rf /scratch/qchem167499.1
# rm -rf /scratch/qchem167499.2
# rm -rf /scratch/qchem167499.3
# rm -rf /scratch/qchem167499.4
# rm -rf /scratch/qchem167499.5
# rm -rf /scratch/qchem167499
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.40_almo.in
# output file: 015_Br-Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167630
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167630
# QCSAVEDIR:
# workdirs:    /scratch/qchem167630.0 -- /scratch/qchem167630.5
# workdir0:    /scratch/qchem167630.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167630.0 -- /scratch/qchem167630.5
# rm -rf /scratch/qchem167630.0
# rm -rf /scratch/qchem167630.1
# rm -rf /scratch/qchem167630.2
# rm -rf /scratch/qchem167630.3
# rm -rf /scratch/qchem167630.4
# rm -rf /scratch/qchem167630.5
# rm -rf /scratch/qchem167630
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_1.50_almo.in
# output file: 015_Br-Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167763
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167763
# QCSAVEDIR:
# workdirs:    /scratch/qchem167763.0 -- /scratch/qchem167763.5
# workdir0:    /scratch/qchem167763.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167763.0 -- /scratch/qchem167763.5
# rm -rf /scratch/qchem167763.0
# rm -rf /scratch/qchem167763.1
# rm -rf /scratch/qchem167763.2
# rm -rf /scratch/qchem167763.3
# rm -rf /scratch/qchem167763.4
# rm -rf /scratch/qchem167763.5
# rm -rf /scratch/qchem167763
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  015_Br-Water_2.00_almo.in
# output file: 015_Br-Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem167885
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem167885
# QCSAVEDIR:
# workdirs:    /scratch/qchem167885.0 -- /scratch/qchem167885.5
# workdir0:    /scratch/qchem167885.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem167885.0 -- /scratch/qchem167885.5
# rm -rf /scratch/qchem167885.0
# rm -rf /scratch/qchem167885.1
# rm -rf /scratch/qchem167885.2
# rm -rf /scratch/qchem167885.3
# rm -rf /scratch/qchem167885.4
# rm -rf /scratch/qchem167885.5
# rm -rf /scratch/qchem167885
