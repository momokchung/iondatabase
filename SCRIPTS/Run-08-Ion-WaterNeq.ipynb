# %%
import os
import ion_gen as ig

# %%
psi4Exe = "/home/kchung25/anaconda3/envs/psi4_19/bin/psi4"
qchemExe = "/home/kchung25/qchem/5.4.0/bin/qchem"

cwd = os.getcwd()

# %%
# MP2

mp2Dir = f"{cwd}/../MP2"
os.chdir(mp2Dir)

for key in ig.ionWaterNeq:
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_mp2.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# SAPT2+

saptDir = f"{cwd}/../SAPT2+"
os.chdir(saptDir)

for key in ig.ionWaterNeq:
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_sapt.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# ALMO

almoDir = f"{cwd}/../ALMO"
os.chdir(almoDir)

for key in ig.ionWaterNeq:
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileNameIn = f"{index}_{key}_{dist:3.2f}_almo.in"
        fileNameOut = f"{index}_{key}_{dist:3.2f}_almo.out"
        os.system(f"{qchemExe} -np 6 -nt 6 {fileNameIn} {fileNameOut}")
# Out:
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.00_almo.in
# output file: 106_Li-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491111
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491111
# QCSAVEDIR:
# workdirs:    /scratch/qchem491111.0 -- /scratch/qchem491111.5
# workdir0:    /scratch/qchem491111.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491111.0 -- /scratch/qchem491111.5
# rm -rf /scratch/qchem491111.0
# rm -rf /scratch/qchem491111.1
# rm -rf /scratch/qchem491111.2
# rm -rf /scratch/qchem491111.3
# rm -rf /scratch/qchem491111.4
# rm -rf /scratch/qchem491111.5
# rm -rf /scratch/qchem491111
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.10_almo.in
# output file: 106_Li-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491160
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491160
# QCSAVEDIR:
# workdirs:    /scratch/qchem491160.0 -- /scratch/qchem491160.5
# workdir0:    /scratch/qchem491160.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491160.0 -- /scratch/qchem491160.5
# rm -rf /scratch/qchem491160.0
# rm -rf /scratch/qchem491160.1
# rm -rf /scratch/qchem491160.2
# rm -rf /scratch/qchem491160.3
# rm -rf /scratch/qchem491160.4
# rm -rf /scratch/qchem491160.5
# rm -rf /scratch/qchem491160
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.20_almo.in
# output file: 106_Li-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491209
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491209
# QCSAVEDIR:
# workdirs:    /scratch/qchem491209.0 -- /scratch/qchem491209.5
# workdir0:    /scratch/qchem491209.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491209.0 -- /scratch/qchem491209.5
# rm -rf /scratch/qchem491209.0
# rm -rf /scratch/qchem491209.1
# rm -rf /scratch/qchem491209.2
# rm -rf /scratch/qchem491209.3
# rm -rf /scratch/qchem491209.4
# rm -rf /scratch/qchem491209.5
# rm -rf /scratch/qchem491209
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.30_almo.in
# output file: 106_Li-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491258
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491258
# QCSAVEDIR:
# workdirs:    /scratch/qchem491258.0 -- /scratch/qchem491258.5
# workdir0:    /scratch/qchem491258.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491258.0 -- /scratch/qchem491258.5
# rm -rf /scratch/qchem491258.0
# rm -rf /scratch/qchem491258.1
# rm -rf /scratch/qchem491258.2
# rm -rf /scratch/qchem491258.3
# rm -rf /scratch/qchem491258.4
# rm -rf /scratch/qchem491258.5
# rm -rf /scratch/qchem491258
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.40_almo.in
# output file: 106_Li-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491309
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491309
# QCSAVEDIR:
# workdirs:    /scratch/qchem491309.0 -- /scratch/qchem491309.5
# workdir0:    /scratch/qchem491309.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491309.0 -- /scratch/qchem491309.5
# rm -rf /scratch/qchem491309.0
# rm -rf /scratch/qchem491309.1
# rm -rf /scratch/qchem491309.2
# rm -rf /scratch/qchem491309.3
# rm -rf /scratch/qchem491309.4
# rm -rf /scratch/qchem491309.5
# rm -rf /scratch/qchem491309
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_1.50_almo.in
# output file: 106_Li-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491359
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491359
# QCSAVEDIR:
# workdirs:    /scratch/qchem491359.0 -- /scratch/qchem491359.5
# workdir0:    /scratch/qchem491359.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491359.0 -- /scratch/qchem491359.5
# rm -rf /scratch/qchem491359.0
# rm -rf /scratch/qchem491359.1
# rm -rf /scratch/qchem491359.2
# rm -rf /scratch/qchem491359.3
# rm -rf /scratch/qchem491359.4
# rm -rf /scratch/qchem491359.5
# rm -rf /scratch/qchem491359
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  106_Li-Water_neq_2.00_almo.in
# output file: 106_Li-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491408
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491408
# QCSAVEDIR:
# workdirs:    /scratch/qchem491408.0 -- /scratch/qchem491408.5
# workdir0:    /scratch/qchem491408.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491408.0 -- /scratch/qchem491408.5
# rm -rf /scratch/qchem491408.0
# rm -rf /scratch/qchem491408.1
# rm -rf /scratch/qchem491408.2
# rm -rf /scratch/qchem491408.3
# rm -rf /scratch/qchem491408.4
# rm -rf /scratch/qchem491408.5
# rm -rf /scratch/qchem491408
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.00_almo.in
# output file: 107_Na-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491458
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491458
# QCSAVEDIR:
# workdirs:    /scratch/qchem491458.0 -- /scratch/qchem491458.5
# workdir0:    /scratch/qchem491458.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491458.0 -- /scratch/qchem491458.5
# rm -rf /scratch/qchem491458.0
# rm -rf /scratch/qchem491458.1
# rm -rf /scratch/qchem491458.2
# rm -rf /scratch/qchem491458.3
# rm -rf /scratch/qchem491458.4
# rm -rf /scratch/qchem491458.5
# rm -rf /scratch/qchem491458
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.10_almo.in
# output file: 107_Na-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491510
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491510
# QCSAVEDIR:
# workdirs:    /scratch/qchem491510.0 -- /scratch/qchem491510.5
# workdir0:    /scratch/qchem491510.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491510.0 -- /scratch/qchem491510.5
# rm -rf /scratch/qchem491510.0
# rm -rf /scratch/qchem491510.1
# rm -rf /scratch/qchem491510.2
# rm -rf /scratch/qchem491510.3
# rm -rf /scratch/qchem491510.4
# rm -rf /scratch/qchem491510.5
# rm -rf /scratch/qchem491510
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.20_almo.in
# output file: 107_Na-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491559
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491559
# QCSAVEDIR:
# workdirs:    /scratch/qchem491559.0 -- /scratch/qchem491559.5
# workdir0:    /scratch/qchem491559.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491559.0 -- /scratch/qchem491559.5
# rm -rf /scratch/qchem491559.0
# rm -rf /scratch/qchem491559.1
# rm -rf /scratch/qchem491559.2
# rm -rf /scratch/qchem491559.3
# rm -rf /scratch/qchem491559.4
# rm -rf /scratch/qchem491559.5
# rm -rf /scratch/qchem491559
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.30_almo.in
# output file: 107_Na-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491608
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491608
# QCSAVEDIR:
# workdirs:    /scratch/qchem491608.0 -- /scratch/qchem491608.5
# workdir0:    /scratch/qchem491608.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491608.0 -- /scratch/qchem491608.5
# rm -rf /scratch/qchem491608.0
# rm -rf /scratch/qchem491608.1
# rm -rf /scratch/qchem491608.2
# rm -rf /scratch/qchem491608.3
# rm -rf /scratch/qchem491608.4
# rm -rf /scratch/qchem491608.5
# rm -rf /scratch/qchem491608
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.40_almo.in
# output file: 107_Na-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491659
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491659
# QCSAVEDIR:
# workdirs:    /scratch/qchem491659.0 -- /scratch/qchem491659.5
# workdir0:    /scratch/qchem491659.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491659.0 -- /scratch/qchem491659.5
# rm -rf /scratch/qchem491659.0
# rm -rf /scratch/qchem491659.1
# rm -rf /scratch/qchem491659.2
# rm -rf /scratch/qchem491659.3
# rm -rf /scratch/qchem491659.4
# rm -rf /scratch/qchem491659.5
# rm -rf /scratch/qchem491659
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_1.50_almo.in
# output file: 107_Na-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491708
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491708
# QCSAVEDIR:
# workdirs:    /scratch/qchem491708.0 -- /scratch/qchem491708.5
# workdir0:    /scratch/qchem491708.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491708.0 -- /scratch/qchem491708.5
# rm -rf /scratch/qchem491708.0
# rm -rf /scratch/qchem491708.1
# rm -rf /scratch/qchem491708.2
# rm -rf /scratch/qchem491708.3
# rm -rf /scratch/qchem491708.4
# rm -rf /scratch/qchem491708.5
# rm -rf /scratch/qchem491708
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  107_Na-Water_neq_2.00_almo.in
# output file: 107_Na-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491757
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491757
# QCSAVEDIR:
# workdirs:    /scratch/qchem491757.0 -- /scratch/qchem491757.5
# workdir0:    /scratch/qchem491757.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491757.0 -- /scratch/qchem491757.5
# rm -rf /scratch/qchem491757.0
# rm -rf /scratch/qchem491757.1
# rm -rf /scratch/qchem491757.2
# rm -rf /scratch/qchem491757.3
# rm -rf /scratch/qchem491757.4
# rm -rf /scratch/qchem491757.5
# rm -rf /scratch/qchem491757
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.00_almo.in
# output file: 108_K-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491808
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491808
# QCSAVEDIR:
# workdirs:    /scratch/qchem491808.0 -- /scratch/qchem491808.5
# workdir0:    /scratch/qchem491808.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491808.0 -- /scratch/qchem491808.5
# rm -rf /scratch/qchem491808.0
# rm -rf /scratch/qchem491808.1
# rm -rf /scratch/qchem491808.2
# rm -rf /scratch/qchem491808.3
# rm -rf /scratch/qchem491808.4
# rm -rf /scratch/qchem491808.5
# rm -rf /scratch/qchem491808
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.10_almo.in
# output file: 108_K-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491857
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491857
# QCSAVEDIR:
# workdirs:    /scratch/qchem491857.0 -- /scratch/qchem491857.5
# workdir0:    /scratch/qchem491857.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491857.0 -- /scratch/qchem491857.5
# rm -rf /scratch/qchem491857.0
# rm -rf /scratch/qchem491857.1
# rm -rf /scratch/qchem491857.2
# rm -rf /scratch/qchem491857.3
# rm -rf /scratch/qchem491857.4
# rm -rf /scratch/qchem491857.5
# rm -rf /scratch/qchem491857
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.20_almo.in
# output file: 108_K-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491907
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491907
# QCSAVEDIR:
# workdirs:    /scratch/qchem491907.0 -- /scratch/qchem491907.5
# workdir0:    /scratch/qchem491907.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491907.0 -- /scratch/qchem491907.5
# rm -rf /scratch/qchem491907.0
# rm -rf /scratch/qchem491907.1
# rm -rf /scratch/qchem491907.2
# rm -rf /scratch/qchem491907.3
# rm -rf /scratch/qchem491907.4
# rm -rf /scratch/qchem491907.5
# rm -rf /scratch/qchem491907
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.30_almo.in
# output file: 108_K-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem491959
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem491959
# QCSAVEDIR:
# workdirs:    /scratch/qchem491959.0 -- /scratch/qchem491959.5
# workdir0:    /scratch/qchem491959.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem491959.0 -- /scratch/qchem491959.5
# rm -rf /scratch/qchem491959.0
# rm -rf /scratch/qchem491959.1
# rm -rf /scratch/qchem491959.2
# rm -rf /scratch/qchem491959.3
# rm -rf /scratch/qchem491959.4
# rm -rf /scratch/qchem491959.5
# rm -rf /scratch/qchem491959
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.40_almo.in
# output file: 108_K-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492008
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492008
# QCSAVEDIR:
# workdirs:    /scratch/qchem492008.0 -- /scratch/qchem492008.5
# workdir0:    /scratch/qchem492008.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492008.0 -- /scratch/qchem492008.5
# rm -rf /scratch/qchem492008.0
# rm -rf /scratch/qchem492008.1
# rm -rf /scratch/qchem492008.2
# rm -rf /scratch/qchem492008.3
# rm -rf /scratch/qchem492008.4
# rm -rf /scratch/qchem492008.5
# rm -rf /scratch/qchem492008
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_1.50_almo.in
# output file: 108_K-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492058
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492058
# QCSAVEDIR:
# workdirs:    /scratch/qchem492058.0 -- /scratch/qchem492058.5
# workdir0:    /scratch/qchem492058.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492058.0 -- /scratch/qchem492058.5
# rm -rf /scratch/qchem492058.0
# rm -rf /scratch/qchem492058.1
# rm -rf /scratch/qchem492058.2
# rm -rf /scratch/qchem492058.3
# rm -rf /scratch/qchem492058.4
# rm -rf /scratch/qchem492058.5
# rm -rf /scratch/qchem492058
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  108_K-Water_neq_2.00_almo.in
# output file: 108_K-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492110
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492110
# QCSAVEDIR:
# workdirs:    /scratch/qchem492110.0 -- /scratch/qchem492110.5
# workdir0:    /scratch/qchem492110.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492110.0 -- /scratch/qchem492110.5
# rm -rf /scratch/qchem492110.0
# rm -rf /scratch/qchem492110.1
# rm -rf /scratch/qchem492110.2
# rm -rf /scratch/qchem492110.3
# rm -rf /scratch/qchem492110.4
# rm -rf /scratch/qchem492110.5
# rm -rf /scratch/qchem492110
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.00_almo.in
# output file: 109_F-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492159
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492159
# QCSAVEDIR:
# workdirs:    /scratch/qchem492159.0 -- /scratch/qchem492159.5
# workdir0:    /scratch/qchem492159.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492159.0 -- /scratch/qchem492159.5
# rm -rf /scratch/qchem492159.0
# rm -rf /scratch/qchem492159.1
# rm -rf /scratch/qchem492159.2
# rm -rf /scratch/qchem492159.3
# rm -rf /scratch/qchem492159.4
# rm -rf /scratch/qchem492159.5
# rm -rf /scratch/qchem492159
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.10_almo.in
# output file: 109_F-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492208
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492208
# QCSAVEDIR:
# workdirs:    /scratch/qchem492208.0 -- /scratch/qchem492208.5
# workdir0:    /scratch/qchem492208.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492208.0 -- /scratch/qchem492208.5
# rm -rf /scratch/qchem492208.0
# rm -rf /scratch/qchem492208.1
# rm -rf /scratch/qchem492208.2
# rm -rf /scratch/qchem492208.3
# rm -rf /scratch/qchem492208.4
# rm -rf /scratch/qchem492208.5
# rm -rf /scratch/qchem492208
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.20_almo.in
# output file: 109_F-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492259
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492259
# QCSAVEDIR:
# workdirs:    /scratch/qchem492259.0 -- /scratch/qchem492259.5
# workdir0:    /scratch/qchem492259.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492259.0 -- /scratch/qchem492259.5
# rm -rf /scratch/qchem492259.0
# rm -rf /scratch/qchem492259.1
# rm -rf /scratch/qchem492259.2
# rm -rf /scratch/qchem492259.3
# rm -rf /scratch/qchem492259.4
# rm -rf /scratch/qchem492259.5
# rm -rf /scratch/qchem492259
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.30_almo.in
# output file: 109_F-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492308
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492308
# QCSAVEDIR:
# workdirs:    /scratch/qchem492308.0 -- /scratch/qchem492308.5
# workdir0:    /scratch/qchem492308.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492308.0 -- /scratch/qchem492308.5
# rm -rf /scratch/qchem492308.0
# rm -rf /scratch/qchem492308.1
# rm -rf /scratch/qchem492308.2
# rm -rf /scratch/qchem492308.3
# rm -rf /scratch/qchem492308.4
# rm -rf /scratch/qchem492308.5
# rm -rf /scratch/qchem492308
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.40_almo.in
# output file: 109_F-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492357
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492357
# QCSAVEDIR:
# workdirs:    /scratch/qchem492357.0 -- /scratch/qchem492357.5
# workdir0:    /scratch/qchem492357.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492357.0 -- /scratch/qchem492357.5
# rm -rf /scratch/qchem492357.0
# rm -rf /scratch/qchem492357.1
# rm -rf /scratch/qchem492357.2
# rm -rf /scratch/qchem492357.3
# rm -rf /scratch/qchem492357.4
# rm -rf /scratch/qchem492357.5
# rm -rf /scratch/qchem492357
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_1.50_almo.in
# output file: 109_F-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492406
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492406
# QCSAVEDIR:
# workdirs:    /scratch/qchem492406.0 -- /scratch/qchem492406.5
# workdir0:    /scratch/qchem492406.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492406.0 -- /scratch/qchem492406.5
# rm -rf /scratch/qchem492406.0
# rm -rf /scratch/qchem492406.1
# rm -rf /scratch/qchem492406.2
# rm -rf /scratch/qchem492406.3
# rm -rf /scratch/qchem492406.4
# rm -rf /scratch/qchem492406.5
# rm -rf /scratch/qchem492406
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  109_F-Water_neq_2.00_almo.in
# output file: 109_F-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492457
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492457
# QCSAVEDIR:
# workdirs:    /scratch/qchem492457.0 -- /scratch/qchem492457.5
# workdir0:    /scratch/qchem492457.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492457.0 -- /scratch/qchem492457.5
# rm -rf /scratch/qchem492457.0
# rm -rf /scratch/qchem492457.1
# rm -rf /scratch/qchem492457.2
# rm -rf /scratch/qchem492457.3
# rm -rf /scratch/qchem492457.4
# rm -rf /scratch/qchem492457.5
# rm -rf /scratch/qchem492457
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.00_almo.in
# output file: 110_Cl-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492506
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492506
# QCSAVEDIR:
# workdirs:    /scratch/qchem492506.0 -- /scratch/qchem492506.5
# workdir0:    /scratch/qchem492506.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492506.0 -- /scratch/qchem492506.5
# rm -rf /scratch/qchem492506.0
# rm -rf /scratch/qchem492506.1
# rm -rf /scratch/qchem492506.2
# rm -rf /scratch/qchem492506.3
# rm -rf /scratch/qchem492506.4
# rm -rf /scratch/qchem492506.5
# rm -rf /scratch/qchem492506
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.10_almo.in
# output file: 110_Cl-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492555
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492555
# QCSAVEDIR:
# workdirs:    /scratch/qchem492555.0 -- /scratch/qchem492555.5
# workdir0:    /scratch/qchem492555.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492555.0 -- /scratch/qchem492555.5
# rm -rf /scratch/qchem492555.0
# rm -rf /scratch/qchem492555.1
# rm -rf /scratch/qchem492555.2
# rm -rf /scratch/qchem492555.3
# rm -rf /scratch/qchem492555.4
# rm -rf /scratch/qchem492555.5
# rm -rf /scratch/qchem492555
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.20_almo.in
# output file: 110_Cl-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492611
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492611
# QCSAVEDIR:
# workdirs:    /scratch/qchem492611.0 -- /scratch/qchem492611.5
# workdir0:    /scratch/qchem492611.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492611.0 -- /scratch/qchem492611.5
# rm -rf /scratch/qchem492611.0
# rm -rf /scratch/qchem492611.1
# rm -rf /scratch/qchem492611.2
# rm -rf /scratch/qchem492611.3
# rm -rf /scratch/qchem492611.4
# rm -rf /scratch/qchem492611.5
# rm -rf /scratch/qchem492611
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.30_almo.in
# output file: 110_Cl-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492665
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492665
# QCSAVEDIR:
# workdirs:    /scratch/qchem492665.0 -- /scratch/qchem492665.5
# workdir0:    /scratch/qchem492665.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492665.0 -- /scratch/qchem492665.5
# rm -rf /scratch/qchem492665.0
# rm -rf /scratch/qchem492665.1
# rm -rf /scratch/qchem492665.2
# rm -rf /scratch/qchem492665.3
# rm -rf /scratch/qchem492665.4
# rm -rf /scratch/qchem492665.5
# rm -rf /scratch/qchem492665
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.40_almo.in
# output file: 110_Cl-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492741
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492741
# QCSAVEDIR:
# workdirs:    /scratch/qchem492741.0 -- /scratch/qchem492741.5
# workdir0:    /scratch/qchem492741.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492741.0 -- /scratch/qchem492741.5
# rm -rf /scratch/qchem492741.0
# rm -rf /scratch/qchem492741.1
# rm -rf /scratch/qchem492741.2
# rm -rf /scratch/qchem492741.3
# rm -rf /scratch/qchem492741.4
# rm -rf /scratch/qchem492741.5
# rm -rf /scratch/qchem492741
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_1.50_almo.in
# output file: 110_Cl-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492813
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492813
# QCSAVEDIR:
# workdirs:    /scratch/qchem492813.0 -- /scratch/qchem492813.5
# workdir0:    /scratch/qchem492813.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492813.0 -- /scratch/qchem492813.5
# rm -rf /scratch/qchem492813.0
# rm -rf /scratch/qchem492813.1
# rm -rf /scratch/qchem492813.2
# rm -rf /scratch/qchem492813.3
# rm -rf /scratch/qchem492813.4
# rm -rf /scratch/qchem492813.5
# rm -rf /scratch/qchem492813
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  110_Cl-Water_neq_2.00_almo.in
# output file: 110_Cl-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492883
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492883
# QCSAVEDIR:
# workdirs:    /scratch/qchem492883.0 -- /scratch/qchem492883.5
# workdir0:    /scratch/qchem492883.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492883.0 -- /scratch/qchem492883.5
# rm -rf /scratch/qchem492883.0
# rm -rf /scratch/qchem492883.1
# rm -rf /scratch/qchem492883.2
# rm -rf /scratch/qchem492883.3
# rm -rf /scratch/qchem492883.4
# rm -rf /scratch/qchem492883.5
# rm -rf /scratch/qchem492883
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.00_almo.in
# output file: 111_Br-Water_neq_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem492951
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem492951
# QCSAVEDIR:
# workdirs:    /scratch/qchem492951.0 -- /scratch/qchem492951.5
# workdir0:    /scratch/qchem492951.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem492951.0 -- /scratch/qchem492951.5
# rm -rf /scratch/qchem492951.0
# rm -rf /scratch/qchem492951.1
# rm -rf /scratch/qchem492951.2
# rm -rf /scratch/qchem492951.3
# rm -rf /scratch/qchem492951.4
# rm -rf /scratch/qchem492951.5
# rm -rf /scratch/qchem492951
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.10_almo.in
# output file: 111_Br-Water_neq_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493031
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493031
# QCSAVEDIR:
# workdirs:    /scratch/qchem493031.0 -- /scratch/qchem493031.5
# workdir0:    /scratch/qchem493031.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493031.0 -- /scratch/qchem493031.5
# rm -rf /scratch/qchem493031.0
# rm -rf /scratch/qchem493031.1
# rm -rf /scratch/qchem493031.2
# rm -rf /scratch/qchem493031.3
# rm -rf /scratch/qchem493031.4
# rm -rf /scratch/qchem493031.5
# rm -rf /scratch/qchem493031
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.20_almo.in
# output file: 111_Br-Water_neq_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493111
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493111
# QCSAVEDIR:
# workdirs:    /scratch/qchem493111.0 -- /scratch/qchem493111.5
# workdir0:    /scratch/qchem493111.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493111.0 -- /scratch/qchem493111.5
# rm -rf /scratch/qchem493111.0
# rm -rf /scratch/qchem493111.1
# rm -rf /scratch/qchem493111.2
# rm -rf /scratch/qchem493111.3
# rm -rf /scratch/qchem493111.4
# rm -rf /scratch/qchem493111.5
# rm -rf /scratch/qchem493111
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.30_almo.in
# output file: 111_Br-Water_neq_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493191
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493191
# QCSAVEDIR:
# workdirs:    /scratch/qchem493191.0 -- /scratch/qchem493191.5
# workdir0:    /scratch/qchem493191.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493191.0 -- /scratch/qchem493191.5
# rm -rf /scratch/qchem493191.0
# rm -rf /scratch/qchem493191.1
# rm -rf /scratch/qchem493191.2
# rm -rf /scratch/qchem493191.3
# rm -rf /scratch/qchem493191.4
# rm -rf /scratch/qchem493191.5
# rm -rf /scratch/qchem493191
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.40_almo.in
# output file: 111_Br-Water_neq_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493267
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493267
# QCSAVEDIR:
# workdirs:    /scratch/qchem493267.0 -- /scratch/qchem493267.5
# workdir0:    /scratch/qchem493267.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493267.0 -- /scratch/qchem493267.5
# rm -rf /scratch/qchem493267.0
# rm -rf /scratch/qchem493267.1
# rm -rf /scratch/qchem493267.2
# rm -rf /scratch/qchem493267.3
# rm -rf /scratch/qchem493267.4
# rm -rf /scratch/qchem493267.5
# rm -rf /scratch/qchem493267
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_1.50_almo.in
# output file: 111_Br-Water_neq_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493347
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493347
# QCSAVEDIR:
# workdirs:    /scratch/qchem493347.0 -- /scratch/qchem493347.5
# workdir0:    /scratch/qchem493347.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493347.0 -- /scratch/qchem493347.5
# rm -rf /scratch/qchem493347.0
# rm -rf /scratch/qchem493347.1
# rm -rf /scratch/qchem493347.2
# rm -rf /scratch/qchem493347.3
# rm -rf /scratch/qchem493347.4
# rm -rf /scratch/qchem493347.5
# rm -rf /scratch/qchem493347
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/iondatabase/ALMO
# input file:  111_Br-Water_neq_2.00_almo.in
# output file: 111_Br-Water_neq_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem493420
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem493420
# QCSAVEDIR:
# workdirs:    /scratch/qchem493420.0 -- /scratch/qchem493420.5
# workdir0:    /scratch/qchem493420.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem493420.0 -- /scratch/qchem493420.5
# rm -rf /scratch/qchem493420.0
# rm -rf /scratch/qchem493420.1
# rm -rf /scratch/qchem493420.2
# rm -rf /scratch/qchem493420.3
# rm -rf /scratch/qchem493420.4
# rm -rf /scratch/qchem493420.5
# rm -rf /scratch/qchem493420
