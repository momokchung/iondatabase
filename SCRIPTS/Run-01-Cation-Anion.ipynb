# %%
import os
import ion_gen as ig

# %%
psi4Exe = "/home/kchung25/anaconda3/envs/psi4_19/bin/psi4"
qchemExe = "/home/kchung25/qchem/5.4.0/bin/qchem"

cwd = os.getcwd()

# %%
# MP2

mp2Dir = f"{cwd}/../MP2"
os.chdir(mp2Dir)

for key,item in ig.catAnEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_mp2.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# SAPT2+

saptDir = f"{cwd}/../SAPT2+"
os.chdir(saptDir)

for key,item in ig.catAnEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_sapt.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# ALMO

almoDir = f"{cwd}/../ALMO"
os.chdir(almoDir)

for key,item in ig.catAnEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileNameIn = f"{index}_{key}_{dist:3.2f}_almo.in"
        fileNameOut = f"{index}_{key}_{dist:3.2f}_almo.out"
        os.system(f"{qchemExe} -np 6 -nt 6 {fileNameIn} {fileNameOut}")
# Out:
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_0.80_almo.in
# output file: 001_Li-F_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94155
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94155
# QCSAVEDIR:
# workdirs:    /scratch/qchem94155.0 -- /scratch/qchem94155.5
# workdir0:    /scratch/qchem94155.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94155.0 -- /scratch/qchem94155.5
# rm -rf /scratch/qchem94155.0
# rm -rf /scratch/qchem94155.1
# rm -rf /scratch/qchem94155.2
# rm -rf /scratch/qchem94155.3
# rm -rf /scratch/qchem94155.4
# rm -rf /scratch/qchem94155.5
# rm -rf /scratch/qchem94155
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_0.90_almo.in
# output file: 001_Li-F_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94218
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94218
# QCSAVEDIR:
# workdirs:    /scratch/qchem94218.0 -- /scratch/qchem94218.5
# workdir0:    /scratch/qchem94218.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94218.0 -- /scratch/qchem94218.5
# rm -rf /scratch/qchem94218.0
# rm -rf /scratch/qchem94218.1
# rm -rf /scratch/qchem94218.2
# rm -rf /scratch/qchem94218.3
# rm -rf /scratch/qchem94218.4
# rm -rf /scratch/qchem94218.5
# rm -rf /scratch/qchem94218
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_0.95_almo.in
# output file: 001_Li-F_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94301
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94301
# QCSAVEDIR:
# workdirs:    /scratch/qchem94301.0 -- /scratch/qchem94301.5
# workdir0:    /scratch/qchem94301.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94301.0 -- /scratch/qchem94301.5
# rm -rf /scratch/qchem94301.0
# rm -rf /scratch/qchem94301.1
# rm -rf /scratch/qchem94301.2
# rm -rf /scratch/qchem94301.3
# rm -rf /scratch/qchem94301.4
# rm -rf /scratch/qchem94301.5
# rm -rf /scratch/qchem94301
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.00_almo.in
# output file: 001_Li-F_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94383
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94383
# QCSAVEDIR:
# workdirs:    /scratch/qchem94383.0 -- /scratch/qchem94383.5
# workdir0:    /scratch/qchem94383.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94383.0 -- /scratch/qchem94383.5
# rm -rf /scratch/qchem94383.0
# rm -rf /scratch/qchem94383.1
# rm -rf /scratch/qchem94383.2
# rm -rf /scratch/qchem94383.3
# rm -rf /scratch/qchem94383.4
# rm -rf /scratch/qchem94383.5
# rm -rf /scratch/qchem94383
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.05_almo.in
# output file: 001_Li-F_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94465
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94465
# QCSAVEDIR:
# workdirs:    /scratch/qchem94465.0 -- /scratch/qchem94465.5
# workdir0:    /scratch/qchem94465.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94465.0 -- /scratch/qchem94465.5
# rm -rf /scratch/qchem94465.0
# rm -rf /scratch/qchem94465.1
# rm -rf /scratch/qchem94465.2
# rm -rf /scratch/qchem94465.3
# rm -rf /scratch/qchem94465.4
# rm -rf /scratch/qchem94465.5
# rm -rf /scratch/qchem94465
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.10_almo.in
# output file: 001_Li-F_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94545
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94545
# QCSAVEDIR:
# workdirs:    /scratch/qchem94545.0 -- /scratch/qchem94545.5
# workdir0:    /scratch/qchem94545.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94545.0 -- /scratch/qchem94545.5
# rm -rf /scratch/qchem94545.0
# rm -rf /scratch/qchem94545.1
# rm -rf /scratch/qchem94545.2
# rm -rf /scratch/qchem94545.3
# rm -rf /scratch/qchem94545.4
# rm -rf /scratch/qchem94545.5
# rm -rf /scratch/qchem94545
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.20_almo.in
# output file: 001_Li-F_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94625
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94625
# QCSAVEDIR:
# workdirs:    /scratch/qchem94625.0 -- /scratch/qchem94625.5
# workdir0:    /scratch/qchem94625.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94625.0 -- /scratch/qchem94625.5
# rm -rf /scratch/qchem94625.0
# rm -rf /scratch/qchem94625.1
# rm -rf /scratch/qchem94625.2
# rm -rf /scratch/qchem94625.3
# rm -rf /scratch/qchem94625.4
# rm -rf /scratch/qchem94625.5
# rm -rf /scratch/qchem94625
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.30_almo.in
# output file: 001_Li-F_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94707
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94707
# QCSAVEDIR:
# workdirs:    /scratch/qchem94707.0 -- /scratch/qchem94707.5
# workdir0:    /scratch/qchem94707.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94707.0 -- /scratch/qchem94707.5
# rm -rf /scratch/qchem94707.0
# rm -rf /scratch/qchem94707.1
# rm -rf /scratch/qchem94707.2
# rm -rf /scratch/qchem94707.3
# rm -rf /scratch/qchem94707.4
# rm -rf /scratch/qchem94707.5
# rm -rf /scratch/qchem94707
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.40_almo.in
# output file: 001_Li-F_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94791
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94791
# QCSAVEDIR:
# workdirs:    /scratch/qchem94791.0 -- /scratch/qchem94791.5
# workdir0:    /scratch/qchem94791.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94791.0 -- /scratch/qchem94791.5
# rm -rf /scratch/qchem94791.0
# rm -rf /scratch/qchem94791.1
# rm -rf /scratch/qchem94791.2
# rm -rf /scratch/qchem94791.3
# rm -rf /scratch/qchem94791.4
# rm -rf /scratch/qchem94791.5
# rm -rf /scratch/qchem94791
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_1.50_almo.in
# output file: 001_Li-F_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94882
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94882
# QCSAVEDIR:
# workdirs:    /scratch/qchem94882.0 -- /scratch/qchem94882.5
# workdir0:    /scratch/qchem94882.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94882.0 -- /scratch/qchem94882.5
# rm -rf /scratch/qchem94882.0
# rm -rf /scratch/qchem94882.1
# rm -rf /scratch/qchem94882.2
# rm -rf /scratch/qchem94882.3
# rm -rf /scratch/qchem94882.4
# rm -rf /scratch/qchem94882.5
# rm -rf /scratch/qchem94882
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  001_Li-F_2.00_almo.in
# output file: 001_Li-F_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem94965
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem94965
# QCSAVEDIR:
# workdirs:    /scratch/qchem94965.0 -- /scratch/qchem94965.5
# workdir0:    /scratch/qchem94965.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem94965.0 -- /scratch/qchem94965.5
# rm -rf /scratch/qchem94965.0
# rm -rf /scratch/qchem94965.1
# rm -rf /scratch/qchem94965.2
# rm -rf /scratch/qchem94965.3
# rm -rf /scratch/qchem94965.4
# rm -rf /scratch/qchem94965.5
# rm -rf /scratch/qchem94965
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_0.80_almo.in
# output file: 002_Li-Cl_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95046
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95046
# QCSAVEDIR:
# workdirs:    /scratch/qchem95046.0 -- /scratch/qchem95046.5
# workdir0:    /scratch/qchem95046.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95046.0 -- /scratch/qchem95046.5
# rm -rf /scratch/qchem95046.0
# rm -rf /scratch/qchem95046.1
# rm -rf /scratch/qchem95046.2
# rm -rf /scratch/qchem95046.3
# rm -rf /scratch/qchem95046.4
# rm -rf /scratch/qchem95046.5
# rm -rf /scratch/qchem95046
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_0.90_almo.in
# output file: 002_Li-Cl_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95113
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95113
# QCSAVEDIR:
# workdirs:    /scratch/qchem95113.0 -- /scratch/qchem95113.5
# workdir0:    /scratch/qchem95113.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95113.0 -- /scratch/qchem95113.5
# rm -rf /scratch/qchem95113.0
# rm -rf /scratch/qchem95113.1
# rm -rf /scratch/qchem95113.2
# rm -rf /scratch/qchem95113.3
# rm -rf /scratch/qchem95113.4
# rm -rf /scratch/qchem95113.5
# rm -rf /scratch/qchem95113
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_0.95_almo.in
# output file: 002_Li-Cl_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95197
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95197
# QCSAVEDIR:
# workdirs:    /scratch/qchem95197.0 -- /scratch/qchem95197.5
# workdir0:    /scratch/qchem95197.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95197.0 -- /scratch/qchem95197.5
# rm -rf /scratch/qchem95197.0
# rm -rf /scratch/qchem95197.1
# rm -rf /scratch/qchem95197.2
# rm -rf /scratch/qchem95197.3
# rm -rf /scratch/qchem95197.4
# rm -rf /scratch/qchem95197.5
# rm -rf /scratch/qchem95197
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.00_almo.in
# output file: 002_Li-Cl_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95281
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95281
# QCSAVEDIR:
# workdirs:    /scratch/qchem95281.0 -- /scratch/qchem95281.5
# workdir0:    /scratch/qchem95281.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95281.0 -- /scratch/qchem95281.5
# rm -rf /scratch/qchem95281.0
# rm -rf /scratch/qchem95281.1
# rm -rf /scratch/qchem95281.2
# rm -rf /scratch/qchem95281.3
# rm -rf /scratch/qchem95281.4
# rm -rf /scratch/qchem95281.5
# rm -rf /scratch/qchem95281
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.05_almo.in
# output file: 002_Li-Cl_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95369
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95369
# QCSAVEDIR:
# workdirs:    /scratch/qchem95369.0 -- /scratch/qchem95369.5
# workdir0:    /scratch/qchem95369.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95369.0 -- /scratch/qchem95369.5
# rm -rf /scratch/qchem95369.0
# rm -rf /scratch/qchem95369.1
# rm -rf /scratch/qchem95369.2
# rm -rf /scratch/qchem95369.3
# rm -rf /scratch/qchem95369.4
# rm -rf /scratch/qchem95369.5
# rm -rf /scratch/qchem95369
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.10_almo.in
# output file: 002_Li-Cl_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95453
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95453
# QCSAVEDIR:
# workdirs:    /scratch/qchem95453.0 -- /scratch/qchem95453.5
# workdir0:    /scratch/qchem95453.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95453.0 -- /scratch/qchem95453.5
# rm -rf /scratch/qchem95453.0
# rm -rf /scratch/qchem95453.1
# rm -rf /scratch/qchem95453.2
# rm -rf /scratch/qchem95453.3
# rm -rf /scratch/qchem95453.4
# rm -rf /scratch/qchem95453.5
# rm -rf /scratch/qchem95453
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.20_almo.in
# output file: 002_Li-Cl_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95537
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95537
# QCSAVEDIR:
# workdirs:    /scratch/qchem95537.0 -- /scratch/qchem95537.5
# workdir0:    /scratch/qchem95537.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95537.0 -- /scratch/qchem95537.5
# rm -rf /scratch/qchem95537.0
# rm -rf /scratch/qchem95537.1
# rm -rf /scratch/qchem95537.2
# rm -rf /scratch/qchem95537.3
# rm -rf /scratch/qchem95537.4
# rm -rf /scratch/qchem95537.5
# rm -rf /scratch/qchem95537
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.30_almo.in
# output file: 002_Li-Cl_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95621
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95621
# QCSAVEDIR:
# workdirs:    /scratch/qchem95621.0 -- /scratch/qchem95621.5
# workdir0:    /scratch/qchem95621.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95621.0 -- /scratch/qchem95621.5
# rm -rf /scratch/qchem95621.0
# rm -rf /scratch/qchem95621.1
# rm -rf /scratch/qchem95621.2
# rm -rf /scratch/qchem95621.3
# rm -rf /scratch/qchem95621.4
# rm -rf /scratch/qchem95621.5
# rm -rf /scratch/qchem95621
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.40_almo.in
# output file: 002_Li-Cl_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95705
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95705
# QCSAVEDIR:
# workdirs:    /scratch/qchem95705.0 -- /scratch/qchem95705.5
# workdir0:    /scratch/qchem95705.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95705.0 -- /scratch/qchem95705.5
# rm -rf /scratch/qchem95705.0
# rm -rf /scratch/qchem95705.1
# rm -rf /scratch/qchem95705.2
# rm -rf /scratch/qchem95705.3
# rm -rf /scratch/qchem95705.4
# rm -rf /scratch/qchem95705.5
# rm -rf /scratch/qchem95705
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_1.50_almo.in
# output file: 002_Li-Cl_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95790
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95790
# QCSAVEDIR:
# workdirs:    /scratch/qchem95790.0 -- /scratch/qchem95790.5
# workdir0:    /scratch/qchem95790.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95790.0 -- /scratch/qchem95790.5
# rm -rf /scratch/qchem95790.0
# rm -rf /scratch/qchem95790.1
# rm -rf /scratch/qchem95790.2
# rm -rf /scratch/qchem95790.3
# rm -rf /scratch/qchem95790.4
# rm -rf /scratch/qchem95790.5
# rm -rf /scratch/qchem95790
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  002_Li-Cl_2.00_almo.in
# output file: 002_Li-Cl_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95876
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95876
# QCSAVEDIR:
# workdirs:    /scratch/qchem95876.0 -- /scratch/qchem95876.5
# workdir0:    /scratch/qchem95876.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95876.0 -- /scratch/qchem95876.5
# rm -rf /scratch/qchem95876.0
# rm -rf /scratch/qchem95876.1
# rm -rf /scratch/qchem95876.2
# rm -rf /scratch/qchem95876.3
# rm -rf /scratch/qchem95876.4
# rm -rf /scratch/qchem95876.5
# rm -rf /scratch/qchem95876
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_0.80_almo.in
# output file: 003_Li-Br_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem95966
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem95966
# QCSAVEDIR:
# workdirs:    /scratch/qchem95966.0 -- /scratch/qchem95966.5
# workdir0:    /scratch/qchem95966.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem95966.0 -- /scratch/qchem95966.5
# rm -rf /scratch/qchem95966.0
# rm -rf /scratch/qchem95966.1
# rm -rf /scratch/qchem95966.2
# rm -rf /scratch/qchem95966.3
# rm -rf /scratch/qchem95966.4
# rm -rf /scratch/qchem95966.5
# rm -rf /scratch/qchem95966
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_0.90_almo.in
# output file: 003_Li-Br_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96054
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96054
# QCSAVEDIR:
# workdirs:    /scratch/qchem96054.0 -- /scratch/qchem96054.5
# workdir0:    /scratch/qchem96054.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96054.0 -- /scratch/qchem96054.5
# rm -rf /scratch/qchem96054.0
# rm -rf /scratch/qchem96054.1
# rm -rf /scratch/qchem96054.2
# rm -rf /scratch/qchem96054.3
# rm -rf /scratch/qchem96054.4
# rm -rf /scratch/qchem96054.5
# rm -rf /scratch/qchem96054
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_0.95_almo.in
# output file: 003_Li-Br_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96144
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96144
# QCSAVEDIR:
# workdirs:    /scratch/qchem96144.0 -- /scratch/qchem96144.5
# workdir0:    /scratch/qchem96144.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96144.0 -- /scratch/qchem96144.5
# rm -rf /scratch/qchem96144.0
# rm -rf /scratch/qchem96144.1
# rm -rf /scratch/qchem96144.2
# rm -rf /scratch/qchem96144.3
# rm -rf /scratch/qchem96144.4
# rm -rf /scratch/qchem96144.5
# rm -rf /scratch/qchem96144
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.00_almo.in
# output file: 003_Li-Br_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96236
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96236
# QCSAVEDIR:
# workdirs:    /scratch/qchem96236.0 -- /scratch/qchem96236.5
# workdir0:    /scratch/qchem96236.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96236.0 -- /scratch/qchem96236.5
# rm -rf /scratch/qchem96236.0
# rm -rf /scratch/qchem96236.1
# rm -rf /scratch/qchem96236.2
# rm -rf /scratch/qchem96236.3
# rm -rf /scratch/qchem96236.4
# rm -rf /scratch/qchem96236.5
# rm -rf /scratch/qchem96236
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.05_almo.in
# output file: 003_Li-Br_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96324
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96324
# QCSAVEDIR:
# workdirs:    /scratch/qchem96324.0 -- /scratch/qchem96324.5
# workdir0:    /scratch/qchem96324.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96324.0 -- /scratch/qchem96324.5
# rm -rf /scratch/qchem96324.0
# rm -rf /scratch/qchem96324.1
# rm -rf /scratch/qchem96324.2
# rm -rf /scratch/qchem96324.3
# rm -rf /scratch/qchem96324.4
# rm -rf /scratch/qchem96324.5
# rm -rf /scratch/qchem96324
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.10_almo.in
# output file: 003_Li-Br_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96417
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96417
# QCSAVEDIR:
# workdirs:    /scratch/qchem96417.0 -- /scratch/qchem96417.5
# workdir0:    /scratch/qchem96417.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96417.0 -- /scratch/qchem96417.5
# rm -rf /scratch/qchem96417.0
# rm -rf /scratch/qchem96417.1
# rm -rf /scratch/qchem96417.2
# rm -rf /scratch/qchem96417.3
# rm -rf /scratch/qchem96417.4
# rm -rf /scratch/qchem96417.5
# rm -rf /scratch/qchem96417
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.20_almo.in
# output file: 003_Li-Br_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96504
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96504
# QCSAVEDIR:
# workdirs:    /scratch/qchem96504.0 -- /scratch/qchem96504.5
# workdir0:    /scratch/qchem96504.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96504.0 -- /scratch/qchem96504.5
# rm -rf /scratch/qchem96504.0
# rm -rf /scratch/qchem96504.1
# rm -rf /scratch/qchem96504.2
# rm -rf /scratch/qchem96504.3
# rm -rf /scratch/qchem96504.4
# rm -rf /scratch/qchem96504.5
# rm -rf /scratch/qchem96504
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.30_almo.in
# output file: 003_Li-Br_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96593
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96593
# QCSAVEDIR:
# workdirs:    /scratch/qchem96593.0 -- /scratch/qchem96593.5
# workdir0:    /scratch/qchem96593.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96593.0 -- /scratch/qchem96593.5
# rm -rf /scratch/qchem96593.0
# rm -rf /scratch/qchem96593.1
# rm -rf /scratch/qchem96593.2
# rm -rf /scratch/qchem96593.3
# rm -rf /scratch/qchem96593.4
# rm -rf /scratch/qchem96593.5
# rm -rf /scratch/qchem96593
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.40_almo.in
# output file: 003_Li-Br_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96684
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96684
# QCSAVEDIR:
# workdirs:    /scratch/qchem96684.0 -- /scratch/qchem96684.5
# workdir0:    /scratch/qchem96684.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96684.0 -- /scratch/qchem96684.5
# rm -rf /scratch/qchem96684.0
# rm -rf /scratch/qchem96684.1
# rm -rf /scratch/qchem96684.2
# rm -rf /scratch/qchem96684.3
# rm -rf /scratch/qchem96684.4
# rm -rf /scratch/qchem96684.5
# rm -rf /scratch/qchem96684
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_1.50_almo.in
# output file: 003_Li-Br_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96771
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96771
# QCSAVEDIR:
# workdirs:    /scratch/qchem96771.0 -- /scratch/qchem96771.5
# workdir0:    /scratch/qchem96771.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96771.0 -- /scratch/qchem96771.5
# rm -rf /scratch/qchem96771.0
# rm -rf /scratch/qchem96771.1
# rm -rf /scratch/qchem96771.2
# rm -rf /scratch/qchem96771.3
# rm -rf /scratch/qchem96771.4
# rm -rf /scratch/qchem96771.5
# rm -rf /scratch/qchem96771
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  003_Li-Br_2.00_almo.in
# output file: 003_Li-Br_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96862
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96862
# QCSAVEDIR:
# workdirs:    /scratch/qchem96862.0 -- /scratch/qchem96862.5
# workdir0:    /scratch/qchem96862.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96862.0 -- /scratch/qchem96862.5
# rm -rf /scratch/qchem96862.0
# rm -rf /scratch/qchem96862.1
# rm -rf /scratch/qchem96862.2
# rm -rf /scratch/qchem96862.3
# rm -rf /scratch/qchem96862.4
# rm -rf /scratch/qchem96862.5
# rm -rf /scratch/qchem96862
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  004_Na-F_0.80_almo.in
# output file: 004_Na-F_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem96951
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem96951
# QCSAVEDIR:
# workdirs:    /scratch/qchem96951.0 -- /scratch/qchem96951.5
# workdir0:    /scratch/qchem96951.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem96951.0 -- /scratch/qchem96951.5
# rm -rf /scratch/qchem96951.0
# rm -rf /scratch/qchem96951.1
# rm -rf /scratch/qchem96951.2
# rm -rf /scratch/qchem96951.3
# rm -rf /scratch/qchem96951.4
# rm -rf /scratch/qchem96951.5
# rm -rf /scratch/qchem96951
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  004_Na-F_0.90_almo.in
# output file: 004_Na-F_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem97039
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem97039
# QCSAVEDIR:
# workdirs:    /scratch/qchem97039.0 -- /scratch/qchem97039.5
# workdir0:    /scratch/qchem97039.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem97039.0 -- /scratch/qchem97039.5
# rm -rf /scratch/qchem97039.0
# rm -rf /scratch/qchem97039.1
# rm -rf /scratch/qchem97039.2
# rm -rf /scratch/qchem97039.3
# rm -rf /scratch/qchem97039.4
# rm -rf /scratch/qchem97039.5
# rm -rf /scratch/qchem97039
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  004_Na-F_0.95_almo.in
# output file: 004_Na-F_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem97126
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem97126
# QCSAVEDIR:
# workdirs:    /scratch/qchem97126.0 -- /scratch/qchem97126.5
# workdir0:    /scratch/qchem97126.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem97126.0 -- /scratch/qchem97126.5
# rm -rf /scratch/qchem97126.0
# rm -rf /scratch/qchem97126.1
# rm -rf /scratch/qchem97126.2
# rm -rf /scratch/qchem97126.3
# rm -rf /scratch/qchem97126.4
# rm -rf /scratch/qchem97126.5
# rm -rf /scratch/qchem97126
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  004_Na-F_1.00_almo.in
# output file: 004_Na-F_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem97213
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem97213
# QCSAVEDIR:
# workdirs:    /scratch/qchem97213.0 -- /scratch/qchem97213.5
# workdir0:    /scratch/qchem97213.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem97213.0 -- /scratch/qchem97213.5
# rm -rf /scratch/qchem97213.0
# rm -rf /scratch/qchem97213.1
# rm -rf /scratch/qchem97213.2
# rm -rf /scratch/qchem97213.3
# ...
# rm -rf /scratch/qchem101806.0
# rm -rf /scratch/qchem101806.1
# rm -rf /scratch/qchem101806.2
# rm -rf /scratch/qchem101806.3
# rm -rf /scratch/qchem101806.4
# rm -rf /scratch/qchem101806.5
# rm -rf /scratch/qchem101806
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  008_K-Cl_2.00_almo.in
# output file: 008_K-Cl_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem101896
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem101896
# QCSAVEDIR:
# workdirs:    /scratch/qchem101896.0 -- /scratch/qchem101896.5
# workdir0:    /scratch/qchem101896.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem101896.0 -- /scratch/qchem101896.5
# rm -rf /scratch/qchem101896.0
# rm -rf /scratch/qchem101896.1
# rm -rf /scratch/qchem101896.2
# rm -rf /scratch/qchem101896.3
# rm -rf /scratch/qchem101896.4
# rm -rf /scratch/qchem101896.5
# rm -rf /scratch/qchem101896
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_0.80_almo.in
# output file: 009_K-Br_0.80_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem101985
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem101985
# QCSAVEDIR:
# workdirs:    /scratch/qchem101985.0 -- /scratch/qchem101985.5
# workdir0:    /scratch/qchem101985.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem101985.0 -- /scratch/qchem101985.5
# rm -rf /scratch/qchem101985.0
# rm -rf /scratch/qchem101985.1
# rm -rf /scratch/qchem101985.2
# rm -rf /scratch/qchem101985.3
# rm -rf /scratch/qchem101985.4
# rm -rf /scratch/qchem101985.5
# rm -rf /scratch/qchem101985
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_0.90_almo.in
# output file: 009_K-Br_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102080
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102080
# QCSAVEDIR:
# workdirs:    /scratch/qchem102080.0 -- /scratch/qchem102080.5
# workdir0:    /scratch/qchem102080.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102080.0 -- /scratch/qchem102080.5
# rm -rf /scratch/qchem102080.0
# rm -rf /scratch/qchem102080.1
# rm -rf /scratch/qchem102080.2
# rm -rf /scratch/qchem102080.3
# rm -rf /scratch/qchem102080.4
# rm -rf /scratch/qchem102080.5
# rm -rf /scratch/qchem102080
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_0.95_almo.in
# output file: 009_K-Br_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102182
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102182
# QCSAVEDIR:
# workdirs:    /scratch/qchem102182.0 -- /scratch/qchem102182.5
# workdir0:    /scratch/qchem102182.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102182.0 -- /scratch/qchem102182.5
# rm -rf /scratch/qchem102182.0
# rm -rf /scratch/qchem102182.1
# rm -rf /scratch/qchem102182.2
# rm -rf /scratch/qchem102182.3
# rm -rf /scratch/qchem102182.4
# rm -rf /scratch/qchem102182.5
# rm -rf /scratch/qchem102182
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.00_almo.in
# output file: 009_K-Br_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102275
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102275
# QCSAVEDIR:
# workdirs:    /scratch/qchem102275.0 -- /scratch/qchem102275.5
# workdir0:    /scratch/qchem102275.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102275.0 -- /scratch/qchem102275.5
# rm -rf /scratch/qchem102275.0
# rm -rf /scratch/qchem102275.1
# rm -rf /scratch/qchem102275.2
# rm -rf /scratch/qchem102275.3
# rm -rf /scratch/qchem102275.4
# rm -rf /scratch/qchem102275.5
# rm -rf /scratch/qchem102275
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.05_almo.in
# output file: 009_K-Br_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102369
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102369
# QCSAVEDIR:
# workdirs:    /scratch/qchem102369.0 -- /scratch/qchem102369.5
# workdir0:    /scratch/qchem102369.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102369.0 -- /scratch/qchem102369.5
# rm -rf /scratch/qchem102369.0
# rm -rf /scratch/qchem102369.1
# rm -rf /scratch/qchem102369.2
# rm -rf /scratch/qchem102369.3
# rm -rf /scratch/qchem102369.4
# rm -rf /scratch/qchem102369.5
# rm -rf /scratch/qchem102369
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.10_almo.in
# output file: 009_K-Br_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102463
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102463
# QCSAVEDIR:
# workdirs:    /scratch/qchem102463.0 -- /scratch/qchem102463.5
# workdir0:    /scratch/qchem102463.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102463.0 -- /scratch/qchem102463.5
# rm -rf /scratch/qchem102463.0
# rm -rf /scratch/qchem102463.1
# rm -rf /scratch/qchem102463.2
# rm -rf /scratch/qchem102463.3
# rm -rf /scratch/qchem102463.4
# rm -rf /scratch/qchem102463.5
# rm -rf /scratch/qchem102463
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.20_almo.in
# output file: 009_K-Br_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102561
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102561
# QCSAVEDIR:
# workdirs:    /scratch/qchem102561.0 -- /scratch/qchem102561.5
# workdir0:    /scratch/qchem102561.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102561.0 -- /scratch/qchem102561.5
# rm -rf /scratch/qchem102561.0
# rm -rf /scratch/qchem102561.1
# rm -rf /scratch/qchem102561.2
# rm -rf /scratch/qchem102561.3
# rm -rf /scratch/qchem102561.4
# rm -rf /scratch/qchem102561.5
# rm -rf /scratch/qchem102561
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.30_almo.in
# output file: 009_K-Br_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102654
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102654
# QCSAVEDIR:
# workdirs:    /scratch/qchem102654.0 -- /scratch/qchem102654.5
# workdir0:    /scratch/qchem102654.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102654.0 -- /scratch/qchem102654.5
# rm -rf /scratch/qchem102654.0
# rm -rf /scratch/qchem102654.1
# rm -rf /scratch/qchem102654.2
# rm -rf /scratch/qchem102654.3
# rm -rf /scratch/qchem102654.4
# rm -rf /scratch/qchem102654.5
# rm -rf /scratch/qchem102654
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.40_almo.in
# output file: 009_K-Br_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102753
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102753
# QCSAVEDIR:
# workdirs:    /scratch/qchem102753.0 -- /scratch/qchem102753.5
# workdir0:    /scratch/qchem102753.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102753.0 -- /scratch/qchem102753.5
# rm -rf /scratch/qchem102753.0
# rm -rf /scratch/qchem102753.1
# rm -rf /scratch/qchem102753.2
# rm -rf /scratch/qchem102753.3
# rm -rf /scratch/qchem102753.4
# rm -rf /scratch/qchem102753.5
# rm -rf /scratch/qchem102753
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_1.50_almo.in
# output file: 009_K-Br_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102845
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102845
# QCSAVEDIR:
# workdirs:    /scratch/qchem102845.0 -- /scratch/qchem102845.5
# workdir0:    /scratch/qchem102845.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102845.0 -- /scratch/qchem102845.5
# rm -rf /scratch/qchem102845.0
# rm -rf /scratch/qchem102845.1
# rm -rf /scratch/qchem102845.2
# rm -rf /scratch/qchem102845.3
# rm -rf /scratch/qchem102845.4
# rm -rf /scratch/qchem102845.5
# rm -rf /scratch/qchem102845
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  009_K-Br_2.00_almo.in
# output file: 009_K-Br_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem102942
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem102942
# QCSAVEDIR:
# workdirs:    /scratch/qchem102942.0 -- /scratch/qchem102942.5
# workdir0:    /scratch/qchem102942.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem102942.0 -- /scratch/qchem102942.5
# rm -rf /scratch/qchem102942.0
# rm -rf /scratch/qchem102942.1
# rm -rf /scratch/qchem102942.2
# rm -rf /scratch/qchem102942.3
# rm -rf /scratch/qchem102942.4
# rm -rf /scratch/qchem102942.5
# rm -rf /scratch/qchem102942
