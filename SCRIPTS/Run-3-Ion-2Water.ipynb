# %%
import os
import ion_gen as ig

# %%
psi4Exe = "/home/kchung25/anaconda3/envs/psi4_19/bin/psi4"
qchemExe = "/home/kchung25/qchem/5.4.0/bin/qchem"

cwd = os.getcwd()

# %%
# MP2

mp2Dir = f"{cwd}/../MP2"
os.chdir(mp2Dir)

for key,item in ig.ion2WaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_mp2.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# SAPT2+

saptDir = f"{cwd}/../SAPT2+"
os.chdir(saptDir)

for key,item in ig.ion2WaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileName = f"{index}_{key}_{dist:3.2f}_sapt.in"
        os.system(f"{psi4Exe} -n 6 {fileName}")

# %%
# ALMO

almoDir = f"{cwd}/../ALMO"
os.chdir(almoDir)

for key,item in ig.ion2WaterEquil.items():
    index = ig.index[key]
    distances = ig.allTwoBody[key]
    for dist in distances:
        fileNameIn = f"{index}_{key}_{dist:3.2f}_almo.in"
        fileNameOut = f"{index}_{key}_{dist:3.2f}_almo.out"
        os.system(f"{qchemExe} -np 6 -nt 6 {fileNameIn} {fileNameOut}")
# Out:
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_0.90_almo.in
# output file: 016_Li-2Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem219098
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem219098
# QCSAVEDIR:
# workdirs:    /scratch/qchem219098.0 -- /scratch/qchem219098.5
# workdir0:    /scratch/qchem219098.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem219098.0 -- /scratch/qchem219098.5
# rm -rf /scratch/qchem219098.0
# rm -rf /scratch/qchem219098.1
# rm -rf /scratch/qchem219098.2
# rm -rf /scratch/qchem219098.3
# rm -rf /scratch/qchem219098.4
# rm -rf /scratch/qchem219098.5
# rm -rf /scratch/qchem219098
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_0.95_almo.in
# output file: 016_Li-2Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem219294
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem219294
# QCSAVEDIR:
# workdirs:    /scratch/qchem219294.0 -- /scratch/qchem219294.5
# workdir0:    /scratch/qchem219294.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem219294.0 -- /scratch/qchem219294.5
# rm -rf /scratch/qchem219294.0
# rm -rf /scratch/qchem219294.1
# rm -rf /scratch/qchem219294.2
# rm -rf /scratch/qchem219294.3
# rm -rf /scratch/qchem219294.4
# rm -rf /scratch/qchem219294.5
# rm -rf /scratch/qchem219294
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.00_almo.in
# output file: 016_Li-2Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem219479
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem219479
# QCSAVEDIR:
# workdirs:    /scratch/qchem219479.0 -- /scratch/qchem219479.5
# workdir0:    /scratch/qchem219479.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem219479.0 -- /scratch/qchem219479.5
# rm -rf /scratch/qchem219479.0
# rm -rf /scratch/qchem219479.1
# rm -rf /scratch/qchem219479.2
# rm -rf /scratch/qchem219479.3
# rm -rf /scratch/qchem219479.4
# rm -rf /scratch/qchem219479.5
# rm -rf /scratch/qchem219479
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.05_almo.in
# output file: 016_Li-2Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem219661
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem219661
# QCSAVEDIR:
# workdirs:    /scratch/qchem219661.0 -- /scratch/qchem219661.5
# workdir0:    /scratch/qchem219661.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem219661.0 -- /scratch/qchem219661.5
# rm -rf /scratch/qchem219661.0
# rm -rf /scratch/qchem219661.1
# rm -rf /scratch/qchem219661.2
# rm -rf /scratch/qchem219661.3
# rm -rf /scratch/qchem219661.4
# rm -rf /scratch/qchem219661.5
# rm -rf /scratch/qchem219661
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.10_almo.in
# output file: 016_Li-2Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem219844
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem219844
# QCSAVEDIR:
# workdirs:    /scratch/qchem219844.0 -- /scratch/qchem219844.5
# workdir0:    /scratch/qchem219844.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem219844.0 -- /scratch/qchem219844.5
# rm -rf /scratch/qchem219844.0
# rm -rf /scratch/qchem219844.1
# rm -rf /scratch/qchem219844.2
# rm -rf /scratch/qchem219844.3
# rm -rf /scratch/qchem219844.4
# rm -rf /scratch/qchem219844.5
# rm -rf /scratch/qchem219844
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.20_almo.in
# output file: 016_Li-2Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220024
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220024
# QCSAVEDIR:
# workdirs:    /scratch/qchem220024.0 -- /scratch/qchem220024.5
# workdir0:    /scratch/qchem220024.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220024.0 -- /scratch/qchem220024.5
# rm -rf /scratch/qchem220024.0
# rm -rf /scratch/qchem220024.1
# rm -rf /scratch/qchem220024.2
# rm -rf /scratch/qchem220024.3
# rm -rf /scratch/qchem220024.4
# rm -rf /scratch/qchem220024.5
# rm -rf /scratch/qchem220024
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.30_almo.in
# output file: 016_Li-2Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220200
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220200
# QCSAVEDIR:
# workdirs:    /scratch/qchem220200.0 -- /scratch/qchem220200.5
# workdir0:    /scratch/qchem220200.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220200.0 -- /scratch/qchem220200.5
# rm -rf /scratch/qchem220200.0
# rm -rf /scratch/qchem220200.1
# rm -rf /scratch/qchem220200.2
# rm -rf /scratch/qchem220200.3
# rm -rf /scratch/qchem220200.4
# rm -rf /scratch/qchem220200.5
# rm -rf /scratch/qchem220200
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.40_almo.in
# output file: 016_Li-2Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220371
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220371
# QCSAVEDIR:
# workdirs:    /scratch/qchem220371.0 -- /scratch/qchem220371.5
# workdir0:    /scratch/qchem220371.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220371.0 -- /scratch/qchem220371.5
# rm -rf /scratch/qchem220371.0
# rm -rf /scratch/qchem220371.1
# rm -rf /scratch/qchem220371.2
# rm -rf /scratch/qchem220371.3
# rm -rf /scratch/qchem220371.4
# rm -rf /scratch/qchem220371.5
# rm -rf /scratch/qchem220371
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_1.50_almo.in
# output file: 016_Li-2Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220533
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220533
# QCSAVEDIR:
# workdirs:    /scratch/qchem220533.0 -- /scratch/qchem220533.5
# workdir0:    /scratch/qchem220533.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220533.0 -- /scratch/qchem220533.5
# rm -rf /scratch/qchem220533.0
# rm -rf /scratch/qchem220533.1
# rm -rf /scratch/qchem220533.2
# rm -rf /scratch/qchem220533.3
# rm -rf /scratch/qchem220533.4
# rm -rf /scratch/qchem220533.5
# rm -rf /scratch/qchem220533
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  016_Li-2Water_2.00_almo.in
# output file: 016_Li-2Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220703
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220703
# QCSAVEDIR:
# workdirs:    /scratch/qchem220703.0 -- /scratch/qchem220703.5
# workdir0:    /scratch/qchem220703.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220703.0 -- /scratch/qchem220703.5
# rm -rf /scratch/qchem220703.0
# rm -rf /scratch/qchem220703.1
# rm -rf /scratch/qchem220703.2
# rm -rf /scratch/qchem220703.3
# rm -rf /scratch/qchem220703.4
# rm -rf /scratch/qchem220703.5
# rm -rf /scratch/qchem220703
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_0.90_almo.in
# output file: 017_Na-2Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem220867
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem220867
# QCSAVEDIR:
# workdirs:    /scratch/qchem220867.0 -- /scratch/qchem220867.5
# workdir0:    /scratch/qchem220867.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem220867.0 -- /scratch/qchem220867.5
# rm -rf /scratch/qchem220867.0
# rm -rf /scratch/qchem220867.1
# rm -rf /scratch/qchem220867.2
# rm -rf /scratch/qchem220867.3
# rm -rf /scratch/qchem220867.4
# rm -rf /scratch/qchem220867.5
# rm -rf /scratch/qchem220867
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_0.95_almo.in
# output file: 017_Na-2Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem221121
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem221121
# QCSAVEDIR:
# workdirs:    /scratch/qchem221121.0 -- /scratch/qchem221121.5
# workdir0:    /scratch/qchem221121.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem221121.0 -- /scratch/qchem221121.5
# rm -rf /scratch/qchem221121.0
# rm -rf /scratch/qchem221121.1
# rm -rf /scratch/qchem221121.2
# rm -rf /scratch/qchem221121.3
# rm -rf /scratch/qchem221121.4
# rm -rf /scratch/qchem221121.5
# rm -rf /scratch/qchem221121
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.00_almo.in
# output file: 017_Na-2Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem221293
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem221293
# QCSAVEDIR:
# workdirs:    /scratch/qchem221293.0 -- /scratch/qchem221293.5
# workdir0:    /scratch/qchem221293.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem221293.0 -- /scratch/qchem221293.5
# rm -rf /scratch/qchem221293.0
# rm -rf /scratch/qchem221293.1
# rm -rf /scratch/qchem221293.2
# rm -rf /scratch/qchem221293.3
# rm -rf /scratch/qchem221293.4
# rm -rf /scratch/qchem221293.5
# rm -rf /scratch/qchem221293
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.05_almo.in
# output file: 017_Na-2Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem221472
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem221472
# QCSAVEDIR:
# workdirs:    /scratch/qchem221472.0 -- /scratch/qchem221472.5
# workdir0:    /scratch/qchem221472.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem221472.0 -- /scratch/qchem221472.5
# rm -rf /scratch/qchem221472.0
# rm -rf /scratch/qchem221472.1
# rm -rf /scratch/qchem221472.2
# rm -rf /scratch/qchem221472.3
# rm -rf /scratch/qchem221472.4
# rm -rf /scratch/qchem221472.5
# rm -rf /scratch/qchem221472
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.10_almo.in
# output file: 017_Na-2Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem221657
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem221657
# QCSAVEDIR:
# workdirs:    /scratch/qchem221657.0 -- /scratch/qchem221657.5
# workdir0:    /scratch/qchem221657.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem221657.0 -- /scratch/qchem221657.5
# rm -rf /scratch/qchem221657.0
# rm -rf /scratch/qchem221657.1
# rm -rf /scratch/qchem221657.2
# rm -rf /scratch/qchem221657.3
# rm -rf /scratch/qchem221657.4
# rm -rf /scratch/qchem221657.5
# rm -rf /scratch/qchem221657
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.20_almo.in
# output file: 017_Na-2Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem221842
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem221842
# QCSAVEDIR:
# workdirs:    /scratch/qchem221842.0 -- /scratch/qchem221842.5
# workdir0:    /scratch/qchem221842.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem221842.0 -- /scratch/qchem221842.5
# rm -rf /scratch/qchem221842.0
# rm -rf /scratch/qchem221842.1
# rm -rf /scratch/qchem221842.2
# rm -rf /scratch/qchem221842.3
# rm -rf /scratch/qchem221842.4
# rm -rf /scratch/qchem221842.5
# rm -rf /scratch/qchem221842
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.30_almo.in
# output file: 017_Na-2Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222025
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222025
# QCSAVEDIR:
# workdirs:    /scratch/qchem222025.0 -- /scratch/qchem222025.5
# workdir0:    /scratch/qchem222025.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222025.0 -- /scratch/qchem222025.5
# rm -rf /scratch/qchem222025.0
# rm -rf /scratch/qchem222025.1
# rm -rf /scratch/qchem222025.2
# rm -rf /scratch/qchem222025.3
# rm -rf /scratch/qchem222025.4
# rm -rf /scratch/qchem222025.5
# rm -rf /scratch/qchem222025
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.40_almo.in
# output file: 017_Na-2Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222194
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222194
# QCSAVEDIR:
# workdirs:    /scratch/qchem222194.0 -- /scratch/qchem222194.5
# workdir0:    /scratch/qchem222194.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222194.0 -- /scratch/qchem222194.5
# rm -rf /scratch/qchem222194.0
# rm -rf /scratch/qchem222194.1
# rm -rf /scratch/qchem222194.2
# rm -rf /scratch/qchem222194.3
# rm -rf /scratch/qchem222194.4
# rm -rf /scratch/qchem222194.5
# rm -rf /scratch/qchem222194
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_1.50_almo.in
# output file: 017_Na-2Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222366
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222366
# QCSAVEDIR:
# workdirs:    /scratch/qchem222366.0 -- /scratch/qchem222366.5
# workdir0:    /scratch/qchem222366.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222366.0 -- /scratch/qchem222366.5
# rm -rf /scratch/qchem222366.0
# rm -rf /scratch/qchem222366.1
# rm -rf /scratch/qchem222366.2
# rm -rf /scratch/qchem222366.3
# rm -rf /scratch/qchem222366.4
# rm -rf /scratch/qchem222366.5
# rm -rf /scratch/qchem222366
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  017_Na-2Water_2.00_almo.in
# output file: 017_Na-2Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222540
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222540
# QCSAVEDIR:
# workdirs:    /scratch/qchem222540.0 -- /scratch/qchem222540.5
# workdir0:    /scratch/qchem222540.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222540.0 -- /scratch/qchem222540.5
# rm -rf /scratch/qchem222540.0
# rm -rf /scratch/qchem222540.1
# rm -rf /scratch/qchem222540.2
# rm -rf /scratch/qchem222540.3
# rm -rf /scratch/qchem222540.4
# rm -rf /scratch/qchem222540.5
# rm -rf /scratch/qchem222540
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_0.90_almo.in
# output file: 018_K-2Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222694
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222694
# QCSAVEDIR:
# workdirs:    /scratch/qchem222694.0 -- /scratch/qchem222694.5
# workdir0:    /scratch/qchem222694.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222694.0 -- /scratch/qchem222694.5
# rm -rf /scratch/qchem222694.0
# rm -rf /scratch/qchem222694.1
# rm -rf /scratch/qchem222694.2
# rm -rf /scratch/qchem222694.3
# rm -rf /scratch/qchem222694.4
# rm -rf /scratch/qchem222694.5
# rm -rf /scratch/qchem222694
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_0.95_almo.in
# output file: 018_K-2Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem222929
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem222929
# QCSAVEDIR:
# workdirs:    /scratch/qchem222929.0 -- /scratch/qchem222929.5
# workdir0:    /scratch/qchem222929.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem222929.0 -- /scratch/qchem222929.5
# rm -rf /scratch/qchem222929.0
# rm -rf /scratch/qchem222929.1
# rm -rf /scratch/qchem222929.2
# rm -rf /scratch/qchem222929.3
# rm -rf /scratch/qchem222929.4
# rm -rf /scratch/qchem222929.5
# rm -rf /scratch/qchem222929
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.00_almo.in
# output file: 018_K-2Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem223157
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem223157
# QCSAVEDIR:
# workdirs:    /scratch/qchem223157.0 -- /scratch/qchem223157.5
# workdir0:    /scratch/qchem223157.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem223157.0 -- /scratch/qchem223157.5
# rm -rf /scratch/qchem223157.0
# rm -rf /scratch/qchem223157.1
# rm -rf /scratch/qchem223157.2
# rm -rf /scratch/qchem223157.3
# rm -rf /scratch/qchem223157.4
# rm -rf /scratch/qchem223157.5
# rm -rf /scratch/qchem223157
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.05_almo.in
# output file: 018_K-2Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem223379
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem223379
# QCSAVEDIR:
# workdirs:    /scratch/qchem223379.0 -- /scratch/qchem223379.5
# workdir0:    /scratch/qchem223379.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem223379.0 -- /scratch/qchem223379.5
# rm -rf /scratch/qchem223379.0
# rm -rf /scratch/qchem223379.1
# rm -rf /scratch/qchem223379.2
# rm -rf /scratch/qchem223379.3
# rm -rf /scratch/qchem223379.4
# rm -rf /scratch/qchem223379.5
# rm -rf /scratch/qchem223379
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.10_almo.in
# output file: 018_K-2Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem223547
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem223547
# QCSAVEDIR:
# workdirs:    /scratch/qchem223547.0 -- /scratch/qchem223547.5
# workdir0:    /scratch/qchem223547.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem223547.0 -- /scratch/qchem223547.5
# rm -rf /scratch/qchem223547.0
# rm -rf /scratch/qchem223547.1
# rm -rf /scratch/qchem223547.2
# rm -rf /scratch/qchem223547.3
# rm -rf /scratch/qchem223547.4
# rm -rf /scratch/qchem223547.5
# rm -rf /scratch/qchem223547
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.20_almo.in
# output file: 018_K-2Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem223732
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem223732
# QCSAVEDIR:
# workdirs:    /scratch/qchem223732.0 -- /scratch/qchem223732.5
# workdir0:    /scratch/qchem223732.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem223732.0 -- /scratch/qchem223732.5
# rm -rf /scratch/qchem223732.0
# rm -rf /scratch/qchem223732.1
# rm -rf /scratch/qchem223732.2
# rm -rf /scratch/qchem223732.3
# rm -rf /scratch/qchem223732.4
# rm -rf /scratch/qchem223732.5
# rm -rf /scratch/qchem223732
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.30_almo.in
# output file: 018_K-2Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem223912
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem223912
# QCSAVEDIR:
# workdirs:    /scratch/qchem223912.0 -- /scratch/qchem223912.5
# workdir0:    /scratch/qchem223912.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem223912.0 -- /scratch/qchem223912.5
# rm -rf /scratch/qchem223912.0
# rm -rf /scratch/qchem223912.1
# rm -rf /scratch/qchem223912.2
# rm -rf /scratch/qchem223912.3
# rm -rf /scratch/qchem223912.4
# rm -rf /scratch/qchem223912.5
# rm -rf /scratch/qchem223912
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.40_almo.in
# output file: 018_K-2Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem224094
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem224094
# QCSAVEDIR:
# workdirs:    /scratch/qchem224094.0 -- /scratch/qchem224094.5
# workdir0:    /scratch/qchem224094.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem224094.0 -- /scratch/qchem224094.5
# rm -rf /scratch/qchem224094.0
# rm -rf /scratch/qchem224094.1
# rm -rf /scratch/qchem224094.2
# rm -rf /scratch/qchem224094.3
# rm -rf /scratch/qchem224094.4
# rm -rf /scratch/qchem224094.5
# rm -rf /scratch/qchem224094
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_1.50_almo.in
# output file: 018_K-2Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem224263
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem224263
# QCSAVEDIR:
# workdirs:    /scratch/qchem224263.0 -- /scratch/qchem224263.5
# workdir0:    /scratch/qchem224263.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem224263.0 -- /scratch/qchem224263.5
# rm -rf /scratch/qchem224263.0
# rm -rf /scratch/qchem224263.1
# rm -rf /scratch/qchem224263.2
# rm -rf /scratch/qchem224263.3
# rm -rf /scratch/qchem224263.4
# rm -rf /scratch/qchem224263.5
# rm -rf /scratch/qchem224263
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  018_K-2Water_2.00_almo.in
# output file: 018_K-2Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem224427
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem224427
# QCSAVEDIR:
# workdirs:    /scratch/qchem224427.0 -- /scratch/qchem224427.5
# workdir0:    /scratch/qchem224427.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem224427.0 -- /scratch/qchem224427.5
# rm -rf /scratch/qchem224427.0
# rm -rf /scratch/qchem224427.1
# rm -rf /scratch/qchem224427.2
# rm -rf /scratch/qchem224427.3
# rm -rf /scratch/qchem224427.4
# rm -rf /scratch/qchem224427.5
# rm -rf /scratch/qchem224427
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_0.90_almo.in
# output file: 019_F-2Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem224577
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem224577
# QCSAVEDIR:
# workdirs:    /scratch/qchem224577.0 -- /scratch/qchem224577.5
# workdir0:    /scratch/qchem224577.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem224577.0 -- /scratch/qchem224577.5
# rm -rf /scratch/qchem224577.0
# rm -rf /scratch/qchem224577.1
# rm -rf /scratch/qchem224577.2
# rm -rf /scratch/qchem224577.3
# rm -rf /scratch/qchem224577.4
# rm -rf /scratch/qchem224577.5
# rm -rf /scratch/qchem224577
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_0.95_almo.in
# output file: 019_F-2Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem224830
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem224830
# QCSAVEDIR:
# workdirs:    /scratch/qchem224830.0 -- /scratch/qchem224830.5
# workdir0:    /scratch/qchem224830.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem224830.0 -- /scratch/qchem224830.5
# rm -rf /scratch/qchem224830.0
# rm -rf /scratch/qchem224830.1
# rm -rf /scratch/qchem224830.2
# rm -rf /scratch/qchem224830.3
# rm -rf /scratch/qchem224830.4
# rm -rf /scratch/qchem224830.5
# rm -rf /scratch/qchem224830
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_1.00_almo.in
# output file: 019_F-2Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem225072
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem225072
# QCSAVEDIR:
# workdirs:    /scratch/qchem225072.0 -- /scratch/qchem225072.5
# workdir0:    /scratch/qchem225072.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem225072.0 -- /scratch/qchem225072.5
# rm -rf /scratch/qchem225072.0
# rm -rf /scratch/qchem225072.1
# rm -rf /scratch/qchem225072.2
# rm -rf /scratch/qchem225072.3
# rm -rf /scratch/qchem225072.4
# rm -rf /scratch/qchem225072.5
# rm -rf /scratch/qchem225072
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_1.05_almo.in
# output file: 019_F-2Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem225308
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem225308
# QCSAVEDIR:
# workdirs:    /scratch/qchem225308.0 -- /scratch/qchem225308.5
# workdir0:    /scratch/qchem225308.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem225308.0 -- /scratch/qchem225308.5
# rm -rf /scratch/qchem225308.0
# rm -rf /scratch/qchem225308.1
# rm -rf /scratch/qchem225308.2
# rm -rf /scratch/qchem225308.3
# rm -rf /scratch/qchem225308.4
# rm -rf /scratch/qchem225308.5
# rm -rf /scratch/qchem225308
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_1.10_almo.in
# output file: 019_F-2Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem225554
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem225554
# QCSAVEDIR:
# workdirs:    /scratch/qchem225554.0 -- /scratch/qchem225554.5
# workdir0:    /scratch/qchem225554.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem225554.0 -- /scratch/qchem225554.5
# rm -rf /scratch/qchem225554.0
# rm -rf /scratch/qchem225554.1
# rm -rf /scratch/qchem225554.2
# rm -rf /scratch/qchem225554.3
# rm -rf /scratch/qchem225554.4
# rm -rf /scratch/qchem225554.5
# rm -rf /scratch/qchem225554
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_1.20_almo.in
# output file: 019_F-2Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem225800
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem225800
# QCSAVEDIR:
# workdirs:    /scratch/qchem225800.0 -- /scratch/qchem225800.5
# workdir0:    /scratch/qchem225800.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem225800.0 -- /scratch/qchem225800.5
# rm -rf /scratch/qchem225800.0
# rm -rf /scratch/qchem225800.1
# rm -rf /scratch/qchem225800.2
# rm -rf /scratch/qchem225800.3
# rm -rf /scratch/qchem225800.4
# rm -rf /scratch/qchem225800.5
# rm -rf /scratch/qchem225800
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  019_F-2Water_1.30_almo.in
# output file: 019_F-2Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# ...
# rm -rf /scratch/qchem228822.3
# rm -rf /scratch/qchem228822.4
# rm -rf /scratch/qchem228822.5
# rm -rf /scratch/qchem228822
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  020_Cl-2Water_1.50_almo.in
# output file: 020_Cl-2Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem229060
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem229060
# QCSAVEDIR:
# workdirs:    /scratch/qchem229060.0 -- /scratch/qchem229060.5
# workdir0:    /scratch/qchem229060.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem229060.0 -- /scratch/qchem229060.5
# rm -rf /scratch/qchem229060.0
# rm -rf /scratch/qchem229060.1
# rm -rf /scratch/qchem229060.2
# rm -rf /scratch/qchem229060.3
# rm -rf /scratch/qchem229060.4
# rm -rf /scratch/qchem229060.5
# rm -rf /scratch/qchem229060
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  020_Cl-2Water_2.00_almo.in
# output file: 020_Cl-2Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem229282
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem229282
# QCSAVEDIR:
# workdirs:    /scratch/qchem229282.0 -- /scratch/qchem229282.5
# workdir0:    /scratch/qchem229282.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem229282.0 -- /scratch/qchem229282.5
# rm -rf /scratch/qchem229282.0
# rm -rf /scratch/qchem229282.1
# rm -rf /scratch/qchem229282.2
# rm -rf /scratch/qchem229282.3
# rm -rf /scratch/qchem229282.4
# rm -rf /scratch/qchem229282.5
# rm -rf /scratch/qchem229282
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_0.90_almo.in
# output file: 021_Br-2Water_0.90_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem229517
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem229517
# QCSAVEDIR:
# workdirs:    /scratch/qchem229517.0 -- /scratch/qchem229517.5
# workdir0:    /scratch/qchem229517.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem229517.0 -- /scratch/qchem229517.5
# rm -rf /scratch/qchem229517.0
# rm -rf /scratch/qchem229517.1
# rm -rf /scratch/qchem229517.2
# rm -rf /scratch/qchem229517.3
# rm -rf /scratch/qchem229517.4
# rm -rf /scratch/qchem229517.5
# rm -rf /scratch/qchem229517
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_0.95_almo.in
# output file: 021_Br-2Water_0.95_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem229836
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem229836
# QCSAVEDIR:
# workdirs:    /scratch/qchem229836.0 -- /scratch/qchem229836.5
# workdir0:    /scratch/qchem229836.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem229836.0 -- /scratch/qchem229836.5
# rm -rf /scratch/qchem229836.0
# rm -rf /scratch/qchem229836.1
# rm -rf /scratch/qchem229836.2
# rm -rf /scratch/qchem229836.3
# rm -rf /scratch/qchem229836.4
# rm -rf /scratch/qchem229836.5
# rm -rf /scratch/qchem229836
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.00_almo.in
# output file: 021_Br-2Water_1.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem230159
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem230159
# QCSAVEDIR:
# workdirs:    /scratch/qchem230159.0 -- /scratch/qchem230159.5
# workdir0:    /scratch/qchem230159.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem230159.0 -- /scratch/qchem230159.5
# rm -rf /scratch/qchem230159.0
# rm -rf /scratch/qchem230159.1
# rm -rf /scratch/qchem230159.2
# rm -rf /scratch/qchem230159.3
# rm -rf /scratch/qchem230159.4
# rm -rf /scratch/qchem230159.5
# rm -rf /scratch/qchem230159
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.05_almo.in
# output file: 021_Br-2Water_1.05_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem230472
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem230472
# QCSAVEDIR:
# workdirs:    /scratch/qchem230472.0 -- /scratch/qchem230472.5
# workdir0:    /scratch/qchem230472.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem230472.0 -- /scratch/qchem230472.5
# rm -rf /scratch/qchem230472.0
# rm -rf /scratch/qchem230472.1
# rm -rf /scratch/qchem230472.2
# rm -rf /scratch/qchem230472.3
# rm -rf /scratch/qchem230472.4
# rm -rf /scratch/qchem230472.5
# rm -rf /scratch/qchem230472
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.10_almo.in
# output file: 021_Br-2Water_1.10_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem230776
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem230776
# QCSAVEDIR:
# workdirs:    /scratch/qchem230776.0 -- /scratch/qchem230776.5
# workdir0:    /scratch/qchem230776.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem230776.0 -- /scratch/qchem230776.5
# rm -rf /scratch/qchem230776.0
# rm -rf /scratch/qchem230776.1
# rm -rf /scratch/qchem230776.2
# rm -rf /scratch/qchem230776.3
# rm -rf /scratch/qchem230776.4
# rm -rf /scratch/qchem230776.5
# rm -rf /scratch/qchem230776
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.20_almo.in
# output file: 021_Br-2Water_1.20_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem231076
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem231076
# QCSAVEDIR:
# workdirs:    /scratch/qchem231076.0 -- /scratch/qchem231076.5
# workdir0:    /scratch/qchem231076.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem231076.0 -- /scratch/qchem231076.5
# rm -rf /scratch/qchem231076.0
# rm -rf /scratch/qchem231076.1
# rm -rf /scratch/qchem231076.2
# rm -rf /scratch/qchem231076.3
# rm -rf /scratch/qchem231076.4
# rm -rf /scratch/qchem231076.5
# rm -rf /scratch/qchem231076
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.30_almo.in
# output file: 021_Br-2Water_1.30_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem231370
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem231370
# QCSAVEDIR:
# workdirs:    /scratch/qchem231370.0 -- /scratch/qchem231370.5
# workdir0:    /scratch/qchem231370.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem231370.0 -- /scratch/qchem231370.5
# rm -rf /scratch/qchem231370.0
# rm -rf /scratch/qchem231370.1
# rm -rf /scratch/qchem231370.2
# rm -rf /scratch/qchem231370.3
# rm -rf /scratch/qchem231370.4
# rm -rf /scratch/qchem231370.5
# rm -rf /scratch/qchem231370
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.40_almo.in
# output file: 021_Br-2Water_1.40_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem231658
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem231658
# QCSAVEDIR:
# workdirs:    /scratch/qchem231658.0 -- /scratch/qchem231658.5
# workdir0:    /scratch/qchem231658.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem231658.0 -- /scratch/qchem231658.5
# rm -rf /scratch/qchem231658.0
# rm -rf /scratch/qchem231658.1
# rm -rf /scratch/qchem231658.2
# rm -rf /scratch/qchem231658.3
# rm -rf /scratch/qchem231658.4
# rm -rf /scratch/qchem231658.5
# rm -rf /scratch/qchem231658
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_1.50_almo.in
# output file: 021_Br-2Water_1.50_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem231954
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem231954
# QCSAVEDIR:
# workdirs:    /scratch/qchem231954.0 -- /scratch/qchem231954.5
# workdir0:    /scratch/qchem231954.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem231954.0 -- /scratch/qchem231954.5
# rm -rf /scratch/qchem231954.0
# rm -rf /scratch/qchem231954.1
# rm -rf /scratch/qchem231954.2
# rm -rf /scratch/qchem231954.3
# rm -rf /scratch/qchem231954.4
# rm -rf /scratch/qchem231954.5
# rm -rf /scratch/qchem231954
# You are running Q-Chem version: 5.4.2
#
# #
# # job setting
# #
# local host:  moses-razer
# current dir: /home/kchung25/Documents/Ponder/IONS/DATABASE/ALMO
# input file:  021_Br-2Water_2.00_almo.in
# output file: 021_Br-2Water_2.00_almo.out
# nprocs     : 6
# nthreads   : 6
# #
# # qchem installation setting
# #
# QC:          /home/kchung25/qchem/5.4.0
# QCAUX:       /home/kchung25/qchem/5.4.0/qcaux
# QCPROG:      /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# QCPROG_S:    /home/kchung25/qchem/5.4.0/exe/qcprog.exe_s
# PARALLEL:    -DSERIAL
# QCMPI:       seq
# #
# # qchem directory setting
# #
# qcrun:       qchem232228
# QCSCRATCH:   /scratch
# QCLOCALSCR:
# QCTMPDIR:    /scratch
# QCFILEPREF:  /scratch/qchem232228
# QCSAVEDIR:
# workdirs:    /scratch/qchem232228.0 -- /scratch/qchem232228.5
# workdir0:    /scratch/qchem232228.0
# partmpdirs =
# #
# # parallel setting
# #
# QCRSH:           ssh
# QCMPI:           seq
# QCMPIRUN:
# QCMACHINEFILE:   /home/kchung25/qchem/5.4.0/bin/mpi/machines
#
#
# #
# # env setting
# #
# exported envs:   QC QCAUX QCSCRATCH QCRUNNAME QCFILEPREF QCPROG QCPROG_S GUIFILE
# remove work dirs /scratch/qchem232228.0 -- /scratch/qchem232228.5
# rm -rf /scratch/qchem232228.0
# rm -rf /scratch/qchem232228.1
# rm -rf /scratch/qchem232228.2
# rm -rf /scratch/qchem232228.3
# rm -rf /scratch/qchem232228.4
# rm -rf /scratch/qchem232228.5
# rm -rf /scratch/qchem232228
